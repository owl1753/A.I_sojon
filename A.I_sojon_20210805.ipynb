# %% [markdown]
# <a href="https://colab.research.google.com/github/owl1753/A.I_sojon/blob/main/A.I_sojon_20210805.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

import time

# %%
from tensorflow.python.client import device_lib
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %%
# !nvidia-smi
# Out:
# Thu Aug  5 09:00:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0    30W /  70W |    104MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
x = np.arange(-1, 1, 0.01)
y = x**2

plt.scatter(x, y)

# %%
print(len(x))
print(x.shape)
# Out:
# 200
# (200,)

# %%
model = Sequential()
model.add(Input(1))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse")

model.fit(x, y, epochs=1000, verbose=0, batch_size=20)

y_ = model.predict(x)

plt.scatter(x, y)
plt.scatter(x, y_, color='r')
plt.show()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])

model.fit(x, y, epochs=1000, verbose=0, batch_size=20)

loss, mse = model.evaluate(x, y)
print("loss=", loss)
print("mse=", mse)

y_ = model.predict(x)

plt.scatter(x, y)
plt.scatter(x, y_, color='r')
plt.show()
# Out:
# 200/200 [==============================] - 0s 139us/sample - loss: 0.0012 - mean_squared_error: 0.0012
# loss= 0.0011723815184086562
# mse= 0.0011723815

# %%
x = np.arange(-1, 1, 0.01)
np.random.shuffle(x)
y = x**2

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y)
plt.show()

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])

model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)

y_ = model.predict(test_x)

plt.scatter(test_x, test_y)
plt.scatter(test_x, y_, color='r')
plt.show()
# Out:
# 80/80 [==============================] - 0s 425us/sample - loss: 0.0026 - mean_squared_error: 0.0026
# loss= 0.0026150662917643784
# mse= 0.0026150665

# %%
plt.scatter(test_x, test_y)
plt.scatter(test_x,y_,color='r')
plt.savefig("base_result.png")

from IPython.display import Image
display(Image("base_result.png"))

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])

start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)

y_ = model.predict(test_x)

plt.scatter(test_x, test_y)
plt.scatter(test_x, y_, color='r')
plt.show()
# Out:
# elapsed : 10.57709264755249
# 80/80 [==============================] - 0s 417us/sample - loss: 0.0035 - mean_squared_error: 0.0035
# loss= 0.003535722056403756
# mse= 0.003535722

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))

y_ = model.predict(test_x)

plt.scatter(test_x, test_y)
plt.scatter(test_x, y_, color='r')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.782760381698608

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

import time


# 모델 정의
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


# 모델 컴파일
model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


# 학습
start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))


# 평가
loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


# 예측
y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.423017263412476
# 80/80 [==============================] - 0s 620us/sample - loss: 0.0023 - mean_squared_error: 0.0023
# loss= 0.0022773572243750097
# mse= 0.0022773573

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.680898427963257
# 80/80 [==============================] - 0s 475us/sample - loss: 0.0018 - mean_squared_error: 0.0018
# loss= 0.0017748167272657156
# mse= 0.0017748168

# %%
from tensorflow.keras.layers import Input

model = Sequential()
model.add(Input((1,)))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    

loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)

display(Image("base_result.png")) # ADD

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.11899471282959
# 80/80 [==============================] - 0s 491us/sample - loss: 0.0921 - mean_squared_error: 0.0921
# loss= 0.09206438660621644
# mse= 0.09206438

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 12.298911333084106
# 80/80 [==============================] - 0s 623us/sample - loss: 0.0017 - mean_squared_error: 0.0017
# loss= 0.0016925480216741563
# mse= 0.001692548

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_30 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_33 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 12.5799241065979
# 80/80 [==============================] - 0s 629us/sample - loss: 6.5657e-04 - mean_squared_error: 6.5657e-04
# loss= 0.0006565718678757549
# mse= 0.0006565719

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_38 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_42 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_43 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_44 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_45 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,021
# Trainable params: 1,021
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 14.90408992767334
# 80/80 [==============================] - 0s 784us/sample - loss: 4.6848e-05 - mean_squared_error: 4.6848e-05
# loss= 4.684785308199935e-05
# mse= 4.6847854e-05

# %%
model = Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(5, activation='tanh', input_shape=(1,)))    # Modify
model.add(Dense(5, activation='tanh'))    # Modify
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 5)                 10
# _________________________________________________________________
# dense_50 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.474151134490967
# 80/80 [==============================] - 0s 696us/sample - loss: 0.0014 - mean_squared_error: 0.0014
# loss= 0.0014262418961152434
# mse= 0.0014262418

# %%
model = Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(2, activation='tanh', input_shape=(1,)))    # Modify
model.add(Dense(2, activation='tanh'))    # modify
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_55 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_56 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_57 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 12.264402866363525
# 80/80 [==============================] - 0s 772us/sample - loss: 0.0017 - mean_squared_error: 0.0017
# loss= 0.001705398946069181
# mse= 0.001705399

# %%
model = Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1, activation='tanh', input_shape=(1,)))      # Modify
model.add(Dense(1, activation='tanh'))      # Modify
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_58 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_59 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_60 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.796045064926147
# 80/80 [==============================] - 0s 818us/sample - loss: 0.0919 - mean_squared_error: 0.0919
# loss= 0.09191051870584488
# mse= 0.09191052

# %%
def get_sin_data(start=0, end=10, step=0.1):
  x = np.arange(start,end,step)
  np.random.shuffle(x)
  y = np.sin(x)

  split_index = int(x.shape[0]*0.6)

  train_x, test_x = x[:split_index], x[split_index:]
  train_y, test_y = y[:split_index], y[split_index:]

  return (train_x, train_y), (test_x, test_y)

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

plt.scatter(train_x,train_y)
plt.show()

plt.scatter(test_x,test_y,color="r")
plt.show()

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_62 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 7.275041580200195
# 40/40 [==============================] - 0s 2ms/sample - loss: 0.1054 - mean_squared_error: 0.1054
# loss= 0.10536861792206764
# mse= 0.105368614

# %%
def fit_one_more(model, train_x, train_y, test_x, test_y, batch_size=20):

  start_time = time.time()
  model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=batch_size)
  print("elapsed : {}".format(time.time() - start_time))    

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()

def fit_n_times(model, train_x, train_y, test_x, test_y, n):
  
  for i in range(n):
    print("{} times fitting".format(i))
    fit_one_more(model, train_x, train_y, test_x, test_y)

# %%
fit_n_times(model, train_x, train_y, test_x, test_y, 10)
# Out:
# 0 times fitting
# elapsed : 6.993839263916016
# 1 times fitting
# elapsed : 6.643826484680176
# 2 times fitting
# elapsed : 6.528955698013306
# 3 times fitting
# elapsed : 6.449888467788696
# 4 times fitting
# elapsed : 6.4551544189453125
# 5 times fitting
# elapsed : 6.515393257141113
# 6 times fitting
# elapsed : 6.493008852005005
# 7 times fitting
# elapsed : 6.5975341796875
# 8 times fitting
# elapsed : 6.88326096534729
# 9 times fitting
# elapsed : 6.914166212081909

# %%
def build_model():

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))

  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])

  return model

def fit_with_batch_sizes(train_x, train_y, test_x, test_y, batch_sizes):

  for batch_size in batch_sizes:
    model = build_model()
    print("batch_size={}".format(batch_size))
    fit_one_more(model, train_x, train_y, test_x, test_y, batch_size)

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

# %%
fit_with_batch_sizes(train_x, train_y, test_x, test_y, batch_sizes=[1,2,5,10,20,50,100,200,500])
# Out:
# batch_size=1
# elapsed : 101.64440703392029
# batch_size=2
# elapsed : 54.87257981300354
# batch_size=5
# elapsed : 23.117701768875122
# batch_size=10
# elapsed : 12.926949739456177
# batch_size=20
# elapsed : 7.622496843338013
# batch_size=50
# elapsed : 5.5332536697387695
# batch_size=100
# elapsed : 3.755878210067749
# batch_size=200
# elapsed : 3.8004870414733887
# batch_size=500
# elapsed : 3.8770127296447754

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_95 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_96 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 8.105426788330078

# %%
print(history.history)
# Out:
# {'loss': [1.0723458727200825, 0.5128874778747559, 0.4759812255700429, 0.4591095248858134, 0.4632602334022522, 0.45767343044281006, 0.4575515886147817, 0.4546257754166921, 0.44535239537556964, 0.44617974758148193, 0.44371231396993, 0.4378795325756073, 0.4321732223033905, 0.4309474031130473, 0.4317160447438558, 0.43721898396809894, 0.4274231394131978, 0.421620637178421, 0.4206390728553136, 0.4189818501472473, 0.4339180092016856, 0.4228130578994751, 0.41678006450335187, 0.4124560256799062, 0.41185595591862995, 0.4101097385088603, 0.41170204679171246, 0.4121408859888713, 0.40489376584688824, 0.4085265100002289, 0.4015536705652873, 0.40118489662806195, 0.39846041798591614, 0.41326266527175903, 0.40839412808418274, 0.40180012583732605, 0.3944300214449565, 0.40923664967219037, 0.39273951450983685, 0.39776386817296344, 0.39034658670425415, 0.41520748535792035, 0.398329754670461, 0.3907642165819804, 0.38654065132141113, 0.3964383701483409, 0.3905257284641266, 0.3861433267593384, 0.38413798809051514, 0.38227733969688416, 0.3811551332473755, 0.3822202483812968, 0.3787466883659363, 0.3789274990558624, 0.38902295629183453, 0.38855212926864624, 0.39655807614326477, 0.3808617393175761, 0.3837967316309611, 0.37620176871617633, 0.3783966302871704, 0.37624597549438477, 0.3737417658170064, 0.3807922104994456, 0.37155967950820923, 0.3882650335629781, 0.37257663905620575, 0.37124067544937134, 0.36837927500406903, 0.3703298668066661, 0.37064339717229206, 0.3698415458202362, 0.3668331305185954, 0.37091394265492755, 0.3679029941558838, 0.3722507357597351, 0.3698394497235616, 0.368678480386734, 0.3653344015280406, 0.3636931876341502, 0.3650485078493754, 0.36668113867441815, 0.36360790332158405, 0.37050487597783405, 0.3657159109910329, 0.3627243638038635, 0.3642895619074504, 0.36499566833178204, 0.3595952292283376, 0.36375640829404193, 0.3573376437028249, 0.3601200381914775, 0.35828044017155963, 0.36260422070821124, 0.36216822266578674, 0.35863883296648663, 0.36365336179733276, 0.3571879069010417, 0.3619082619746526, 0.3557933568954468, 0.3554713527361552, 0.3576505780220032, 0.3525937696297963, 0.3593914806842804, 0.35626744230588275, 0.36837976177533466, 0.35373905301094055, 0.35122165083885193, 0.3549302816390991, 0.3675386607646942, 0.3508992592493693, 0.35255738099416095, 0.35052244861920673, 0.35946287711461383, 0.34979739785194397, 0.34754152099291485, 0.35158876578013104, 0.3501901129881541, 0.3516256511211395, 0.3491235872109731, 0.3531343638896942, 0.345026433467865, 0.3543846706549327, 0.3444053332010905, 0.34803541501363117, 0.34728121757507324, 0.3506711622079213, 0.35035695632298786, 0.3565068443616231, 0.3423956632614136, 0.3486765921115875, 0.3429197371006012, 0.3418826957543691, 0.34137608110904694, 0.35685884952545166, 0.3485605816046397, 0.34299395481745404, 0.3493753870328267, 0.35171682635943097, 0.339606374502182, 0.33789320786794025, 0.33843980232874554, 0.33878756562868756, 0.33677615722020465, 0.34742608666419983, 0.3375286857287089, 0.34688324729601544, 0.3374959925810496, 0.34174397587776184, 0.33524097005526227, 0.3381224771340688, 0.3360476593176524, 0.334344615538915, 0.33504530787467957, 0.33661356568336487, 0.3326531300942103, 0.3563365836938222, 0.33307600021362305, 0.3306535581747691, 0.3304906189441681, 0.33346109588940936, 0.32940499981244403, 0.3394153316815694, 0.34321823716163635, 0.33342820405960083, 0.3517475426197052, 0.33324970801671344, 0.347020963827769, 0.335324764251709, 0.33023430903752643, 0.3309985448916753, 0.326502521832784, 0.3333899478117625, 0.3368244369824727, 0.32902525862058, 0.3242320517698924, 0.32416853308677673, 0.34298068284988403, 0.3308904767036438, 0.32502199212710065, 0.3279035786787669, 0.33250386516253155, 0.34695539871851605, 0.32951762278874713, 0.33011819918950397, 0.32582658032576245, 0.32303233941396076, 0.33341069022814435, 0.319633424282074, 0.3203771412372589, 0.3417903780937195, 0.3288546105225881, 0.32164264221986133, 0.32027621070543927, 0.3176429867744446, 0.32914297779401 ...

# %%
plt.plot(history.history['loss'])

# %%
# (train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.0001)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

print(train_x.shape)

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_97 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_98 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_99 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# (60000,)
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.2860 - mean_squared_error: 0.2860
# Epoch 2/5
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.1390 - mean_squared_error: 0.1390
# Epoch 3/5
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.0927 - mean_squared_error: 0.0927
# Epoch 4/5
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0721 - mean_squared_error: 0.0721
# Epoch 5/5
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.0522 - mean_squared_error: 0.0522
# elapsed : 33.01978349685669

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=1, batch_size=20, validation_data=(test_x, test_y))
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_101 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_102 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60 samples, validate on 40 samples
# Epoch 1/1000
# 60/60 [==============================] - 0s 7ms/sample - loss: 0.4988 - mean_squared_error: 0.4988 - val_loss: 0.4099 - val_mean_squared_error: 0.4099
# Epoch 2/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.4871 - mean_squared_error: 0.4871 - val_loss: 0.3899 - val_mean_squared_error: 0.3899
# Epoch 3/1000
# 60/60 [==============================] - 0s 238us/sample - loss: 0.4824 - mean_squared_error: 0.4824 - val_loss: 0.3891 - val_mean_squared_error: 0.3891
# Epoch 4/1000
# 60/60 [==============================] - 0s 239us/sample - loss: 0.4819 - mean_squared_error: 0.4819 - val_loss: 0.3867 - val_mean_squared_error: 0.3867
# Epoch 5/1000
# 60/60 [==============================] - 0s 264us/sample - loss: 0.4804 - mean_squared_error: 0.4804 - val_loss: 0.3775 - val_mean_squared_error: 0.3775
# Epoch 6/1000
# 60/60 [==============================] - 0s 241us/sample - loss: 0.4755 - mean_squared_error: 0.4755 - val_loss: 0.3746 - val_mean_squared_error: 0.3746
# Epoch 7/1000
# 60/60 [==============================] - 0s 243us/sample - loss: 0.4833 - mean_squared_error: 0.4833 - val_loss: 0.3714 - val_mean_squared_error: 0.3714
# Epoch 8/1000
# 60/60 [==============================] - 0s 248us/sample - loss: 0.4788 - mean_squared_error: 0.4788 - val_loss: 0.3693 - val_mean_squared_error: 0.3693
# Epoch 9/1000
# 60/60 [==============================] - 0s 258us/sample - loss: 0.4743 - mean_squared_error: 0.4743 - val_loss: 0.3705 - val_mean_squared_error: 0.3705
# Epoch 10/1000
# 60/60 [==============================] - 0s 248us/sample - loss: 0.4746 - mean_squared_error: 0.4746 - val_loss: 0.3739 - val_mean_squared_error: 0.3739
# Epoch 11/1000
# 60/60 [==============================] - 0s 296us/sample - loss: 0.4824 - mean_squared_error: 0.4824 - val_loss: 0.3732 - val_mean_squared_error: 0.3732
# Epoch 12/1000
# 60/60 [==============================] - 0s 285us/sample - loss: 0.4696 - mean_squared_error: 0.4696 - val_loss: 0.3728 - val_mean_squared_error: 0.3728
# Epoch 13/1000
# 60/60 [==============================] - 0s 333us/sample - loss: 0.4657 - mean_squared_error: 0.4657 - val_loss: 0.3684 - val_mean_squared_error: 0.3684
# Epoch 14/1000
# 60/60 [==============================] - 0s 255us/sample - loss: 0.4666 - mean_squared_error: 0.4666 - val_loss: 0.3653 - val_mean_squared_error: 0.3653
# Epoch 15/1000
# 60/60 [==============================] - 0s 435us/sample - loss: 0.4621 - mean_squared_error: 0.4621 - val_loss: 0.3640 - val_mean_squared_error: 0.3640
# Epoch 16/1000
# 60/60 [==============================] - 0s 286us/sample - loss: 0.4686 - mean_squared_error: 0.4686 - val_loss: 0.3672 - val_mean_squared_error: 0.3672
# Epoch 17/1000
# 60/60 [==============================] - 0s 296us/sample - loss: 0.4603 - mean_squared_error: 0.4603 - val_loss: 0.3625 - val_mean_squared_error: 0.3625
# Epoch 18/1000
# 60/60 [==============================] - 0s 252us/sample - loss: 0.4617 - mean_squared_error: 0.4617 - val_loss: 0.3597 - val_mean_squared_error: 0.3597
# Epoch 19/1000
# 60/60 [==============================] - 0s 262us/sample - loss: 0.4602 - mean_squared_error: 0.4602 - val_loss: 0.3567 - val_mean_squared_error: 0.3567
# Epoch 20/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.4586 - mean_squared_error: 0.4586 - val_loss: 0.3558 - val_mean_squared_error: 0.3558
# Epoch 21/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4583 - mean_squared_error: 0.4583 - val_loss: 0.3560 - val_mean_squared_error: 0.3560
# Epoch 22/1000
# 60/60 [==============================] - 0s 360us/sample - loss: 0.4553 - mean_squared_error: 0.4553 - val_loss: 0.3555 - val_mean_squared_error: 0.3555
# Epoch 23/1000
# 60/60 [==============================] - 0s 270us/sample - loss: 0.4618 - mean_squared_error: 0.4618 - val_loss: 0.3586 - val_mean_squared_error: 0.3586
# Epoch 24/1000
# 60/60 [==============================] - 0s 266us/sample - loss: 0.4561 - mean_squared_error: 0.4561 - val_loss: 0.3573 - val_mean_squared_error: 0.3573
# Epoch 25/1000
# 60/60 [==============================] - 0s 249us/sample - loss: 0.4653 - mean_squared_error: 0.4653 - val_loss: 0.3505 - val_mean_squared_error: 0.3505
# Epoch 26/1000
# 60/60 [==============================] - 0s 282us/sample - loss: 0.4564 - mean_squared_error: 0.4564 - val_loss: 0.3491 - val_mean_squared_error: 0.3491
# Epoch 27/1000
# 60/60 [==============================] - 0s 260us/sample - loss: 0.4601 - mean_squared_error: 0.4601 - val_loss: 0.3475 - val_mean_squared_error: 0.3475
# Epoch 28/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.4556 - mean_squared_error: 0.4556 - val_loss: 0.3504 - val_mean_squared_error: 0.3504
# Epoch 29/1000
# 60/60 [==============================] - 0s 260us/sample - loss: 0.4608 - mean_squared_error: 0.4608 - val_loss: 0.3541 - val_mean_squared_error: 0.3541
# Epoch 30/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.4543 - mean_squared_error: 0.4543 - val_loss: 0.3526 - val_mean_squared_error: 0.3526
# Epoch 31/1000
# 60/60 [==============================] - 0s 262us/sample - loss: 0.4577 - mean_squared_error: 0.4577 - val_loss: 0.3518 - val_mean_squared_error: 0.3518
# Epoch 32/1000
# 60/60 [==============================] - 0s 326us/sample - loss: 0.4493 - mean_squared_error: 0.4493 - val_loss: 0.3481 - val_mean_squared_error: 0.3481
# Epoch 33/1000
# 60/60 [==============================] - 0s 285us/sample - loss: 0.4580 - mean_squared_error: 0.4580 - val_loss: 0.3490 - val_mean_squared_error: 0.3490
# Epoch 34/1000
# 60/60 [==============================] - 0s 386us/sample - loss: 0.4460 - mean_squared_error: 0.4460 - val_loss: 0.3456 - val_mean_squared_error: 0.3456
# Epoch 35/1000
# 60/60 [==============================] - 0s 258us/sample - loss: 0.4487 - mean_squared_error: 0.4487 - val_loss: 0.3472 - val_mean_squared_error: 0.3472
# Epoch 36/1000
# 60/60 [==============================] - 0s 331us/sample - loss: 0.4499 - mean_squared_error: 0.4499 - val_loss: 0.3461 - val_mean_squared_error: 0.3461
# Epoch 37/1000
# 60/60 [==============================] - 0s 371us/sample - loss: 0.4496 - mean_squared_error: 0.4496 - val_loss: 0.3431 - val_mean_squared_error: 0.3431
# Epoch 38/1000
# 60/60 [==============================] - 0s 253us/sample - loss: 0.4447 - mean_squared_error: 0.4447 - val_loss: 0.3402 - val_mean_squared_error: 0.3402
# Epoch 39/1000
# 60/60 [==============================] - 0s 282us/sample - loss: 0.4439 - mean_squared_error: 0.4439 - val_loss: 0.3414 - val_mean_squared_error: 0.3414
# Epoch 40/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4472 - mean_squared_error: 0.4472 - val_loss: 0.3393 - val_mean_squared_error: 0.3393
# Epoch 41/1000
# 60/60 [==============================] - 0s 334us/sample - loss: 0.4536 - mean_squared_error: 0.4536 - val_loss: 0.3412 - val_mean_squared_error: 0.3412
# Epoch 42/1000
# 60/60 [==============================] - 0s 259us/sample - loss: 0.4491 - mean_squared_error: 0.4491 - val_loss: 0.3443 - val_mean_squared_error: 0.3443
# Epoch 43/1000
# 60/60 [==============================] - 0s 259us/sample - loss: 0.4425 - mean_squared_error: 0.4425 - val_loss: 0.3384 - val_mean_squared_error: 0.3384
# Epoch 44/1000
# 60/60 [==============================] - 0s 238us/sample - loss: 0.4414 - mean_squared_error: 0.4414 - val_loss: 0.3355 - val_mean_squared_error: 0.3355
# Epoch 45/1000
# 60/60 [==============================] - 0s 240us/sample - loss: 0.4426 - mean_squared_error: 0.4426 - val_loss: 0.3337 - val_mean_squared_error: 0.3337
# Epoch 46/1000
# 60/60 [==============================] - 0s 266us/sample - loss: 0.4406 - mean_squared_error: 0.4406 - val_loss: 0.3331 - val_mean_squared_error: 0.3331
# Epoch 47/1000
# 60/60 [==============================] - 0s 274us/sample - loss: 0.4383 - mean_squared_error: 0.4383 - val_loss: 0.3330 - val_mean_squared_error: 0.3330
# Epoch 48/1000
# 60/60 [==============================] - 0s 245us/sample - loss: 0.4396 - mean_squared_error: 0.4396 - val_loss: 0.3313 - val_mean_squared_error: 0.3313
# Epoch 49/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4385 - mean_squared_error: 0.4385 - val_loss: 0.3330 - val_mean_squared_error: 0.3330
# Epoch 50/1000
# 60/60 [==============================] - 0s 344us/sample - loss: 0.4408 - mean_squared_error: 0.4408 - val_loss: 0.3295 - val_mean_squared_error: 0.3295
# Epoch 51/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4368 - mean_squared_error: 0.4368 - val_loss: 0.3306 - val_mean_squared_error: 0.3306
# Epoch 52/1000
# 60/60 [==============================] - 0s 397us/sample - loss: 0.4376 - mean_squared_error: 0.4376 - val_loss: 0.3299 - val_mean_squared_error: 0.3299
# Epoch 53/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4368 - mean_squared_error: 0.4368 - val_loss: 0.3293 - val_mean_squared_error: 0.3293
# Epoch 54/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4405 - mean_squared_error: 0.4405 - val_loss: 0.3314 - val_mean_squared_error: 0.3314
# Epoch 55/1000
# 60/60 [==============================] - 0s 292us/sample - loss: 0.4350 - mean_squared_error: 0.4350 - val_loss: 0.3321 - val_mean_squared_error: 0.3321
# Epoch 56/1000
# 60/60 [==============================] - 0s 316us/sample - loss: 0.4376 - mean_squared_error: 0.4376 - val_loss: 0.3273 - val_mean_squared_error: 0.3273
# Epoch 57/1000
# 60/60 [==============================] - 0s 294us/sample - loss: 0.4335 - mean_squared_error: 0.4335 - val_loss: 0.3283 - val_mean_squared_error: 0.3283
# Epoch 58/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.4356 - mean_squared_error: 0.4356 - val_loss: 0.3262 - val_mean_squared_error: 0.3262
# Epoch 59/1000
# 60/60 [==============================] - 0s 293us/sample - loss: 0.4346 - mean_squared_error: 0.4346 - val_loss: 0.3297 - val_mean_squared_error: 0.3297
# Epoch 60/1000
# 60/60 [==============================] - 0s 386us/sample - loss: 0.4325 - mean_squared_error: 0.4325 - val_loss: 0.3294 - val_mean_squared_error: 0.3294
# Epoch 61/1000
# 60/60 [==============================] - 0s 281us/sample - loss: 0.4375 - mean_squared_error: 0.4375 - val_loss: 0.3279 - val_mean_squared_error: 0.3279
# Epoch 62/1000
# 60/60 [==============================] - 0s 267us/sample - loss: 0.4322 - mean_squared_error: 0.4322 - val_loss: 0.3257 - val_mean_squared_error: 0.3257
# Epoch 63/1000
# 60/60 [==============================] - 0s 239us/sample - loss: 0.4346 - mean_squared_error: 0.4346 - val_loss: 0.3229 - val_mean_squared_error: 0.3229
# Epoch 64/1000
# 60/60 [==============================] - 0s 251us/sample - loss: 0.4386 - mean_squared_error: 0.4386 - val_loss: 0.3293 - val_mean_squared_error: 0.3293
# Epoch 65/1000
# 60/60 [==============================] - 0s 259us/sample - loss: 0.4347 - mean_squared_error: 0.4347 - val_loss: 0.3242 - val_mean_squared_error: 0.3242
# Epoch 66/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4304 - mean_squared_error: 0.4304 - val_loss: 0.3232 - val_mean_squared_error: 0.3232
# Epoch 67/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.4294 - mean_squared_error: 0.4294 - val_loss: 0.3242 - val_mean_squared_error: 0.3242
# Epoch 68/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4295 - mean_squared_error: 0.4295 - val_loss: 0.3243 - val_mean_squared_error: 0.3243
# Epoch 69/1000
# 60/60 [==============================] - 0s 264us/sample - loss: 0.4348 - mean_squared_error: 0.4348 - val_loss: 0.3283 - val_mean_squared_error: 0.3283
# Epoch 70/1000
# 60/60 [==============================] - 0s 277us/sample - loss: 0.4311 - mean_squared_error: 0.4311 - val_loss: 0.3277 - val_mean_squared_error: 0.3277
# Epoch 71/1000
# 60/60 [==============================] - 0s 276us/sample - loss: 0.4315 - mean_squared_error: 0.4315 - val_loss: 0.3236 - val_mean_squared_error: 0.3236
# Epoch 72/1000
# 60/60 [==============================] - 0s 261us/sample - loss: 0.4288 - mean_squared_error: 0.4288 - val_loss: 0.3238 - val_mean_squared_error: 0.3238
# Epoch 73/1000
# 60/60 [==============================] - 0s 331us/sample - loss: 0.4328 - mean_squared_error: 0.4328 - val_loss: 0.3249 - val_mean_squared_error: 0.3249
# Epoch 74/1000
# 60/60 [==============================] - 0s 446us/sample - loss: 0.4273 - mean_squared_error: 0.4273 - val_loss: 0.3218 - val_mean_squared_error: 0.3218
# Epoch 75/1000
# 60/60 [==============================] - 0s 264us/sample - loss: 0.4270 - mean_squared_error: 0.4270 - val_loss: 0.3228 - val_mean_squared_error: 0.3228
# Epoch 76/1000
# 60/60 [==============================] - 0s 250us/sample - loss: 0.4341 - mean_squared_error: 0.4341 - val_loss: 0.3226 - val_mean_squared_error: 0.3226
# Epoch 77/1000
# 60/60 [==============================] - 0s 292us/sample - loss: 0.4327 - mean_squared_error: 0.4327 - val_loss: 0.3217 - val_mean_squared_error: 0.3217
# Epoch 78/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.4260 - mean_squared_error: 0.4260 - val_loss: 0.3197 - val_mean_squared_error: 0.3197
# Epoch 79/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.4268 - mean_squared_error: 0.4268 - val_loss: 0.3192 - val_mean_squared_error: 0.3192
# Epoch 80/1000
# 60/60 [==============================] - 0s 409us/sample - loss: 0.4257 - mean_squared_error: 0.4257 - val_loss: 0.3204 - val_mean_squared_error: 0.3204
# Epoch 81/1000
# 60/60 [==============================] - 0s 356us/sample - loss: 0.4256 - mean_squared_error: 0.4256 - val_loss: 0.3214 - val_mean_squared_error: 0.3214
# Epoch 82/1000
# 60/60 [==============================] - 0s 305us/sample - loss: 0.4245 - mean_squared_error: 0.4245 - val_loss: 0.3201 - val_mean_squared_error: 0.3201
# Epoch 83/1000
# 60/60 [==============================] - 0s 371us/sample - loss: 0.4270 - mean_squared_error: 0.4270 - val_loss: 0.3222 - val_mean_squared_error: 0.3222
# Epoch 84/1000
# 60/60 [==============================] - 0s 259us/sample - loss: 0.4250 - mean_squared_error: 0.4250 - val_loss: 0.3223 - val_mean_squared_error: 0.3223
# Epoch 85/1000
# 60/60 [==============================] - 0s 286us/sample - loss: 0.4266 - mean_squared_error: 0.4266 - val_loss: 0.3167 - val_mean_squared_error: 0.3167
# Epoch 86/1000
# 60/60 [==============================] - 0s 374us/sample - loss: 0.4261 - mean_squared_error: 0.4261 - val_loss: 0.3144 - val_mean_squared_error: 0.3144
# Epoch 87/1000
# 60/60 [==============================] - 0s 273us/sample - loss: 0.4261 - mean_squared_error: 0.4261 - val_loss: 0.3142 - val_mean_squared_error: 0.3142
# Epoch 88/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4282 - mean_squared_error: 0.4282 - val_loss: 0.3118 - val_mean_squared_error: 0.3118
# Epoch 89/1000
# 60/60 [==============================] - 0s 235us/sample - loss: 0.4267 - mean_squared_error: 0.4267 - val_loss: 0.3187 - val_mean_squared_error: 0.3187
# Epoch 90/1000
# 60/60 [==============================] - 0s 353us/sample - loss: 0.4227 - mean_squared_error: 0.4227 - val_loss: 0.3192 - val_mean_squared_error: 0.3192
# Epoch 91/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4241 - mean_squared_error: 0.4241 - val_loss: 0.3143 - val_mean_squared_error: 0.3143
# Epoch 92/1000
# 60/60 [==============================] - 0s 248us/sample - loss: 0.4419 - mean_squared_error: 0.4419 - val_loss: 0.3125 - val_mean_squared_error: 0.3125
# Epoch 93/1000
# 60/60 [==============================] - 0s 290us/sample - loss: 0.4216 - mean_squared_error: 0.4216 - val_loss: 0.3136 - val_mean_squared_error: 0.3136
# Epoch 94/1000
# 60/60 [==============================] - 0s 268us/sample - loss: 0.4346 - mean_squared_error: 0.4346 - val_loss: 0.3112 - val_mean_squared_error: 0.3112
# Epoch 95/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.4201 - mean_squared_error: 0.4201 - val_loss: 0.3140 - val_mean_squared_error: 0.3140
# Epoch 96/1000
# 60/60 [==============================] - 0s 287us/sample - loss: 0.4287 - mean_squared_error: 0.4287 - val_loss: 0.3182 - val_mean_squared_error: 0.3182
# Epoch 97/1000
# 60/60 [==============================] - 0s 255us/sample - loss: 0.4199 - mean_squared_error: 0.4199 - val_loss: 0.3167 - val_mean_squared_error: 0.3167
# Epoch 98/1000
# 60/60 [==============================] - 0s 281us/sample - loss: 0.4202 - mean_squared_error: 0.4202 - val_loss: 0.3140 - val_mean_squared_error: 0.3140
# Epoch 99/1000
# 60/60 [==============================] - 0s 302us/sample - loss: 0.4202 - mean_squared_error: 0.4202 - val_loss: 0.3143 - val_mean_squared_error: 0.3143
# Epoch 100/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.4222 - mean_squared_error: 0.4222 - val_loss: 0.3178 - val_mean_squared_error: 0.3178
# Epoch 101/1000
# 60/60 [==============================] - 0s 326us/sample - loss: 0.4219 - mean_squared_error: 0.4219 - val_loss: 0.3171 - val_mean_squared_error: 0.3171
# Epoch 102/1000
# 60/60 [==============================] - 0s 268us/sample - loss: 0.4213 - mean_squared_error: 0.4213 - val_loss: 0.3173 - val_mean_squared_error: 0.3173
# Epoch 103/1000
# 60/60 [==============================] - 0s 308us/sample - loss: 0.4193 - mean_squared_error: 0.4193 - val_loss: 0.3142 - val_mean_squared_error: 0.3142
# Epoch 104/1000
# 60/60 [==============================] - 0s 285us/sample - loss: 0.4184 - mean_squared_error: 0.4184 - val_loss: 0.3155 - val_mean_squared_error: 0.3155
# Epoch 105/1000
# 60/60 [==============================] - 0s 303us/sample - loss: 0.4193 - mean_squared_error: 0.4193 - val_loss: 0.3160 - val_mean_squared_error: 0.3160
# Epoch 106/1000
# 60/60 [==============================] - 0s 240us/sample - loss: 0.4250 - mean_squared_error: 0.4250 - val_loss: 0.3110 - val_mean_squared_error: 0.3110
# Epoch 107/1000
# 60/60 [==============================] - 0s 249us/sample - loss: 0.4249 - mean_squared_error: 0.4249 - val_loss: 0.3141 - val_mean_squared_error: 0.3141
# Epoch 108/1000
# 60/60 [==============================] - 0s 232us/sample - loss: 0.4162 - mean_squared_error: 0.4162 - val_loss: 0.3110 - val_mean_squared_error: 0.3110
# Epoch 109/1000
# 60/60 [==============================] - 0s 340us/sample - loss: 0.4168 - mean_squared_error: 0.4168 - val_loss: 0.3084 - val_mean_squared_error: 0.3084
# Epoch 110/1000
# 60/60 [==============================] - 0s 420us/sample - loss: 0.4200 - mean_squared_error: 0.4200 - val_loss: 0.3062 - val_mean_squared_error: 0.3062
# Epoch 111/1000
# 60/60 [==============================] - 0s 294us/sample - loss: 0.4167 - mean_squared_error: 0.4167 - val_loss: 0.3111 - val_mean_squared_error: 0.3111
# Epoch 112/1000
# 60/60 [==============================] - 0s 257us/sample - loss: 0.4168 - mean_squared_error: 0.4168 - val_loss: 0.3132 - val_mean_squared_error: 0.3132
# Epoch 113/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.4175 - mean_squared_error: 0.4175 - val_loss: 0.3090 - val_mean_squared_error: 0.3090
# Epoch 114/1000
# 60/60 [==============================] - 0s 348us/sample - loss: 0.4159 - mean_squared_error: 0.4159 - val_loss: 0.3107 - val_mean_squared_error: 0.3107
# Epoch 115/1000
# 60/60 [==============================] - 0s 269us/sample - loss: 0.4171 - mean_squared_error: 0.4171 - val_loss: 0.3082 - val_mean_squared_error: 0.3082
# Epoch 116/1000
# 60/60 [==============================] - 0s 243us/sample - loss: 0.4240 - mean_squared_error: 0.4240 - val_loss: 0.3028 - val_mean_squared_error: 0.3028
# Epoch 117/1000
# 60/60 [==============================] - 0s 239us/sample - loss: 0.4205 - mean_squared_error: 0.4205 - val_loss: 0.3015 - val_mean_squared_error: 0.3015
# Epoch 118/1000
# 60/60 [==============================] - 0s 258us/sample - loss: 0.4189 - mean_squared_error: 0.4189 - val_loss: 0.3020 - val_mean_squared_error: 0.3020
# Epoch 119/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.4133 - mean_squared_error: 0.4133 - val_loss: 0.3041 - val_mean_squared_error: 0.3041
# Epoch 120/1000
# 60/60 [==============================] - 0s 234us/sample - loss: 0.4215 - mean_squared_error: 0.4215 - val_loss: 0.3094 - val_mean_squared_error: 0.3094
# Epoch 121/1000
# 60/60 [==============================] - 0s 248us/sample - loss: 0.4193 - mean_squared_error: 0.4193 - val_loss: 0.3083 - val_mean_squared_error: 0.3083
# Epoch 122/1000
# 60/60 [==============================] - 0s 259us/sample - loss: 0.4214 - mean_squared_error: 0.4214 - val_loss: 0.3043 - val_mean_squared_error: 0.3043
# Epoch 123/1000
# 60/60 [==============================] - 0s 278us/sample - loss: 0.4166 - mean_squared_error: 0.4166 - val_loss: 0.3018 - val_mean_squared_error: 0.3018
# Epoch 124/1000
# 60/60 [==============================] - 0s 305us/sample - loss: 0.4224 - mean_squared_error: 0.4224 - val_loss: 0.3013 - val_mean_squared_error: 0.3013
# Epoch 125/1000
# 60/60 [==============================] - 0s 412us/sample - loss: 0.4142 - mean_squared_error: 0.4142 - val_loss: 0.3079 - val_mean_squared_error: 0.3079
# Epoch 126/1000
# 60/60 [==============================] - 0s 287us/sample - loss: 0.4105 - mean_squared_error: 0.4105 - val_loss: 0.3056 - val_mean_squared_error: 0.3056
# Epoch 127/1000
# 60/60 [==============================] - 0s 403us/sample - loss: 0.4143 - mean_squared_error: 0.4143 - val_loss: 0.3105 - val_mean_squared_error: 0.3105
# Epoch 128/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.4113 - mean_squared_error: 0.4113 - val_loss: 0.3070 - val_mean_squared_error: 0.3070
# Epoch 129/1000
# 60/60 [==============================] - 0s 246us/sample - loss: 0.4107 - mean_squared_error: 0.4107 - val_loss: 0.3086 - val_mean_squared_error: 0.3086
# Epoch 130/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.4091 - mean_squared_error: 0.4091 - val_loss: 0.3086 - val_mean_squared_error: 0.3086
# Epoch 131/1000
# 60/60 [==============================] - 0s 237us/sample - loss: 0.4079 - mean_squared_error: 0.4079 - val_loss: 0.3065 - val_mean_squared_error: 0.3065
# Epoch 132/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4124 - mean_squared_error: 0.4124 - val_loss: 0.3101 - val_mean_squared_error: 0.3101
# Epoch 133/1000
# 60/60 [==============================] - 0s 284us/sample - loss: 0.4090 - mean_squared_error: 0.4090 - val_loss: 0.3039 - val_mean_squared_error: 0.3039
# Epoch 134/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.4074 - mean_squared_error: 0.4074 - val_loss: 0.3057 - val_mean_squared_error: 0.3057
# Epoch 135/1000
# 60/60 [==============================] - 0s 356us/sample - loss: 0.4068 - mean_squared_error: 0.4068 - val_loss: 0.3037 - val_mean_squared_error: 0.3037
# Epoch 136/1000
# 60/60 [==============================] - 0s 264us/sample - loss: 0.4120 - mean_squared_error: 0.4120 - val_loss: 0.3095 - val_mean_squared_error: 0.3095
# Epoch 137/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4073 - mean_squared_error: 0.4073 - val_loss: 0.3077 - val_mean_squared_error: 0.3077
# Epoch 138/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4064 - mean_squared_error: 0.4064 - val_loss: 0.3074 - val_mean_squared_error: 0.3074
# Epoch 139/1000
# 60/60 [==============================] - 0s 294us/sample - loss: 0.4076 - mean_squared_error: 0.4076 - val_loss: 0.3020 - val_mean_squared_error: 0.3020
# Epoch 140/1000
# 60/60 [==============================] - 0s 274us/sample - loss: 0.4090 - mean_squared_error: 0.4090 - val_loss: 0.3045 - val_mean_squared_error: 0.3045
# Epoch 141/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.4085 - mean_squared_error: 0.4085 - val_loss: 0.3046 - val_mean_squared_error: 0.3046
# Epoch 142/1000
# 60/60 [==============================] - 0s 241us/sample - loss: 0.4079 - mean_squared_error: 0.4079 - val_loss: 0.3024 - val_mean_squared_error: 0.3024
# Epoch 143/1000
# 60/60 [==============================] - 0s 336us/sample - loss: 0.4087 - mean_squared_error: 0.4087 - val_loss: 0.2976 - val_mean_squared_error: 0.2976
# Epoch 144/1000
# 60/60 [==============================] - 0s 308us/sample - loss: 0.4052 - mean_squared_error: 0.4052 - val_loss: 0.2975 - val_mean_squared_error: 0.2975
# Epoch 145/1000
# 60/60 [==============================] - 0s 233us/sample - loss: 0.4039 - mean_squared_error: 0.4039 - val_loss: 0.3016 - val_mean_squared_error: 0.3016
# Epoch 146/1000
# 60/60 [==============================] - 0s 296us/sample - loss: 0.4077 - mean_squared_error: 0.4077 - val_loss: 0.2974 - val_mean_squared_error: 0.2974
# Epoch 147/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4029 - mean_squared_error: 0.4029 - val_loss: 0.2988 - val_mean_squared_error: 0.2988
# Epoch 148/1000
# 60/60 [==============================] - 0s 315us/sample - loss: 0.4052 - mean_squared_error: 0.4052 - val_loss: 0.3032 - val_mean_squared_error: 0.3032
# Epoch 149/1000
# 60/60 [==============================] - 0s 256us/sample - loss: 0.4194 - mean_squared_error: 0.4194 - val_loss: 0.3034 - val_mean_squared_error: 0.3034
# Epoch 150/1000
# 60/60 [==============================] - 0s 236us/sample - loss: 0.4019 - mean_squared_error: 0.4019 - val_loss: 0.3036 - val_mean_squared_error: 0.3036
# Epoch 151/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.4039 - mean_squared_error: 0.4039 - val_loss: 0.3005 - val_mean_squared_error: 0.3005
# Epoch 152/1000
# 60/60 [==============================] - 0s 286us/sample - loss: 0.4008 - mean_squared_error: 0.4008 - val_loss: 0.2998 - val_mean_squared_error: 0.2998
# Epoch 153/1000
# 60/60 [==============================] - 0s 262us/sample - loss: 0.4012 - mean_squared_error: 0.4012 - val_loss: 0.3024 - val_mean_squared_error: 0.3024
# Epoch 154/1000
# 60/60 [==============================] - 0s 250us/sample - loss: 0.4005 - mean_squared_error: 0.4005 - val_loss: 0.3025 - val_mean_squared_error: 0.3025
# Epoch 155/1000
# 60/60 [==============================] - 0s 337us/sample - loss: 0.3997 - mean_squared_error: 0.3997 - val_loss: 0.2993 - val_mean_squared_error: 0.2993
# Epoch 156/1000
# 60/60 [==============================] - 0s 247us/sample - loss: 0.4040 - mean_squared_error: 0.4040 - val_loss: 0.2972 - val_mean_squared_error: 0.2972
# Epoch 157/1000
# 60/60 [==============================] - 0s 243us/sample - loss: 0.4077 - mean_squared_error: 0.4077 - val_loss: 0.2957 - val_mean_squared_error: 0.2957
# Epoch 158/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.4101 - mean_squared_error: 0.4101 - val_loss: 0.2995 - val_mean_squared_error: 0.2995
# Epoch 159/1000
# 60/60 [==============================] - 0s 274us/sample - loss: 0.3997 - mean_squared_error: 0.3997 - val_loss: 0.2961 - val_mean_squared_error: 0.2961
# Epoch 160/1000
# 60/60 [==============================] - 0s 240us/sample - loss: 0.4043 - mean_squared_error: 0.4043 - val_loss: 0.3038 - val_mean_squared_error: 0.3038
# Epoch 161/1000
# 60/60 [==============================] - 0s 358us/sample - loss: 0.4035 - mean_squared_error: 0.4035 - val_loss: 0.3060 - val_mean_squared_error: 0.3060
# Epoch 162/1000
# 60/60 [==============================] - 0s 274us/sample - loss: 0.4019 - mean_squared_error: 0.4019 - val_loss: 0.2947 - val_mean_squared_error: 0.2947
# Epoch 163/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.4016 - mean_squared_error: 0.4016 - val_loss: 0.2952 - val_mean_squared_error: 0.2952
# Epoch 164/1000
# 60/60 [==============================] - 0s 244us/sample - loss: 0.3961 - mean_squared_error: 0.3961 - val_loss: 0.2963 - val_mean_squared_error: 0.2963
# Epoch 165/1000
# 60/60 [==============================] - 0s 286us/sample - loss: 0.3989 - mean_squared_error: 0.3989 - val_loss: 0.2989 - val_mean_squared_error: 0.2989
# Epoch 166/1000
# 60/60 [==============================] - 0s 277us/sample - loss: 0.3995 - mean_squared_error: 0.3995 - val_loss: 0.2928 - val_mean_squared_error: 0.2928
# Epoch 167/1000
# 60/60 [==============================] - 0s 313us/sample - loss: 0.4002 - mean_squared_error: 0.4002 - val_loss: 0.2995 - val_mean_squared_error: 0.2995
# Epoch 168/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4062 - mean_squared_error: 0.4062 - val_loss: 0.3067 - val_mean_squared_error: 0.3067
# Epoch 169/1000
# 60/60 [==============================] - 0s 265us/sample - loss: 0.3983 - mean_squared_error: 0.3983 - val_loss: 0.2950 - val_mean_squared_error: 0.2950
# Epoch 170/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.4009 - mean_squared_error: 0.4009 - val_loss: 0.2983 - val_mean_squared_error: 0.2983
# Epoch 171/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.3960 - mean_squared_error: 0.3960 - val_loss: 0.2921 - val_mean_squared_error: 0.2921
# Epoch 172/1000
# 60/60 [==============================] - 0s 303us/sample - loss: 0.4027 - mean_squared_error: 0.4027 - val_loss: 0.2935 - val_mean_squared_error: 0.2935
# Epoch 173/1000
# 60/60 [==============================] - 0s 285us/sample - loss: 0.3970 - mean_squared_error: 0.3970 - val_loss: 0.2971 - val_mean_squared_error: 0.2971
# Epoch 174/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.3964 - mean_squared_error: 0.3964 - val_loss: 0.3009 - val_mean_squared_error: 0.3009
# Epoch 175/1000
# 60/60 [==============================] - 0s 381us/sample - loss: 0.3932 - mean_squared_error: 0.3932 - val_loss: 0.2975 - val_mean_squared_error: 0.2975
# Epoch 176/1000
# 60/60 [==============================] - 0s 309us/sample - loss: 0.3970 - mean_squared_error: 0.3970 - val_loss: 0.3002 - val_mean_squared_error: 0.3002
# Epoch 177/1000
# 60/60 [==============================] - 0s 350us/sample - loss: 0.3922 - mean_squared_error: 0.3922 - val_loss: 0.2933 - val_mean_squared_error: 0.2933
# Epoch 178/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.3910 - mean_squared_error: 0.3910 - val_loss: 0.2926 - val_mean_squared_error: 0.2926
# Epoch 179/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.3939 - mean_squared_error: 0.3939 - val_loss: 0.2942 - val_mean_squared_error: 0.2942
# Epoch 180/1000
# 60/60 [==============================] - 0s 276us/sample - loss: 0.3924 - mean_squared_error: 0.3924 - val_loss: 0.2977 - val_mean_squared_error: 0.2977
# Epoch 181/1000
# 60/60 [==============================] - 0s 280us/sample - loss: 0.3918 - mean_squared_error: 0.3918 - val_loss: 0.2914 - val_mean_squared_error: 0.2914
# Epoch 182/1000
# 60/60 [==============================] - 0s 295us/sample - loss: 0.3913 - mean_squared_error: 0.3913 - val_loss: 0.2883 - val_mean_squared_error: 0.2883
# Epoch 183/1000
# 60/60 [==============================] - 0s 256us/sample - loss: 0.3896 - mean_squared_error: 0.3896 - val_loss: 0.2914 - val_mean_squared_error: 0.2914
# Epoch 184/1000
# 60/60 [==============================] - 0s 296us/sample - loss: 0.3912 - mean_squared_error: 0.3912 - val_loss: 0.2892 - val_mean_squared_error: 0.2892
# Epoch 185/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.3996 - mean_squared_error: 0.3996 - val_loss: 0.2958 - val_mean_squared_error: 0.2958
# Epoch 186/1000
# 60/60 [==============================] - 0s 411us/sample - loss: 0.3885 - mean_squared_error: 0.3885 - val_loss: 0.2943 - val_mean_squared_error: 0.2943
# Epoch 187/1000
# 60/60 [==============================] - 0s 389us/sample - loss: 0.3898 - mean_squared_error: 0.3898 - val_loss: 0.2970 - val_mean_squared_error: 0.2970
# Epoch 188/1000
# 60/60 [==============================] - 0s 336us/sample - loss: 0.3898 - mean_squared_error: 0.3898 - val_loss: 0.2906 - val_mean_squared_error: 0.2906
# Epoch 189/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.3923 - mean_squared_error: 0.3923 - val_loss: 0.2843 - val_mean_squared_error: 0.2843
# Epoch 190/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.3886 - mean_squared_error: 0.3886 - val_loss: 0.2860 - val_mean_squared_error: 0.2860
# Epoch 191/1000
# 60/60 [==============================] - 0s 474us/sample - loss: 0.3883 - mean_squared_error: 0.3883 - val_loss: 0.2929 - val_mean_squared_error: 0.2929
# Epoch 192/1000
# 60/60 [==============================] - 0s 278us/sample - loss: 0.3869 - mean_squared_error: 0.3869 - val_loss: 0.2945 - val_mean_squared_error: 0.2945
# Epoch 193/1000
# 60/60 [==============================] - 0s 277us/sample - loss: 0.3929 - mean_squared_error: 0.3929 - val_loss: 0.2858 - val_mean_squared_error: 0.2858
# Epoch 194/1000
# 60/60 [==============================] - 0s 281us/sample - loss: 0.3881 - mean_squared_error: 0.3881 - val_loss: 0.2850 - val_mean_squared_error: 0.2850
# Epoch 195/1000
# 60/60 [==============================] - 0s 321us/sample - loss: 0.3926 - mean_squared_error: 0.3926 - val_loss: 0.2845 - val_mean_squared_error: 0.2845
# Epoch 196/1000
# 60/60 [==============================] - 0s 366us/sample - loss: 0.3863 - mean_squared_error: 0.3863 - val_loss: 0.2906 - val_mean_squared_error: 0.2906
# Epoch 197/1000
# 60/60 [==============================] - 0s 368us/sample - loss: 0.3941 - mean_squared_error: 0.3941 - val_loss: 0.2934 - val_mean_squared_error: 0.2934
# Epoch 198/1000
# 60/60 [==============================] - 0s 326us/sample - loss: 0.3835 - mean_squared_error: 0.3835 - val_loss: 0.2876 - val_mean_squared_error: 0.2876
# Epoch 199/1000
# 60/60 [==============================] - 0s 286us/sample - loss: 0.3866 - mean_squared_error: 0.3866 - val_loss: 0.2824 - val_mean_squared_error: 0.2824
# Epoch 200/1000
# 60/60 [==============================] - 0s 273us/sample - loss: 0.3839 - mean_squared_error: 0.3839 - val_loss: 0.2893 - val_mean_squared_error: 0.2893
# Epoch 201/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.3956 - mean_squared_error: 0.3956 - val_loss: 0.2889 - val_mean_squared_error: 0.2889
# Epoch 202/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.3814 - mean_squared_error: 0.3814 - val_loss: 0.2872 - val_mean_squared_error: 0.2872
# Epoch 203/1000
# 60/60 [==============================] - 0s 434us/sample - loss: 0.3817 - mean_squared_error: 0.3817 - val_loss: 0.2839 - val_mean_squared_error: 0.2839
# Epoch 204/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.3897 - mean_squared_error: 0.3897 - val_loss: 0.2853 - val_mean_squared_error: 0.2853
# Epoch 205/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.3857 - mean_squared_error: 0.3857 - val_loss: 0.2916 - val_mean_squared_error: 0.2916
# Epoch 206/1000
# 60/60 [==============================] - 0s 309us/sample - loss: 0.3801 - mean_squared_error: 0.3801 - val_loss: 0.2895 - val_mean_squared_error: 0.2895
# Epoch 207/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.3805 - mean_squared_error: 0.3805 - val_loss: 0.2853 - val_mean_squared_error: 0.2853
# Epoch 208/1000
# 60/60 [==============================] - 0s 310us/sample - loss: 0.3809 - mean_squared_error: 0.3809 - val_loss: 0.2849 - val_mean_squared_error: 0.2849
# Epoch 209/1000
# 60/60 [==============================] - 0s 288us/sample - loss: 0.3825 - mean_squared_error: 0.3825 - val_loss: 0.2817 - val_mean_squared_error: 0.2817
# Epoch 210/1000
# 60/60 [==============================] - 0s 321us/sample - loss: 0.3822 - mean_squared_error: 0.3822 - val_loss: 0.2906 - val_mean_squared_error: 0.2906
# Epoch 211/1000
# 60/60 [==============================] - 0s 353us/sample - loss: 0.3841 - mean_squared_error: 0.3841 - val_loss: 0.2856 - val_mean_squared_error: 0.2856
# Epoch 212/1000
# 60/60 [==============================] - 0s 369us/sample - loss: 0.3771 - mean_squared_error: 0.3771 - val_loss: 0.2844 - val_mean_squared_error: 0.2844
# Epoch 213/1000
# 60/60 [==============================] - 0s 290us/sample - loss: 0.3803 - mean_squared_error: 0.3803 - val_loss: 0.2854 - val_mean_squared_error: 0.2854
# Epoch 214/1000
# 60/60 [==============================] - 0s 375us/sample - loss: 0.3801 - mean_squared_error: 0.3801 - val_loss: 0.2823 - val_mean_squared_error: 0.2823
# Epoch 215/1000
# 60/60 [==============================] - 0s 343us/sample - loss: 0.3800 - mean_squared_error: 0.3800 - val_loss: 0.2869 - val_mean_squared_error: 0.2869
# Epoch 216/1000
# 60/60 [==============================] - 0s 311us/sample - loss: 0.3888 - mean_squared_error: 0.3888 - val_loss: 0.2989 - val_mean_squared_error: 0.2989
# Epoch 217/1000
# 60/60 [==============================] - 0s 320us/sample - loss: 0.3803 - mean_squared_error: 0.3803 - val_loss: 0.2902 - val_mean_squared_error: 0.2902
# Epoch 218/1000
# 60/60 [==============================] - 0s 271us/sample - loss: 0.3765 - mean_squared_error: 0.3765 - val_loss: 0.2839 - val_mean_squared_error: 0.2839
# Epoch 219/1000
# 60/60 [==============================] - 0s 341us/sample - loss: 0.3760 - mean_squared_error: 0.3760 - val_loss: 0.2808 - val_mean_squared_error: 0.2808
# Epoch 220/1000
# 60/60 [==============================] - 0s 372us/sample - loss: 0.4009 - mean_squared_error: 0.4009 - val_loss: 0.2700 - val_mean_squared_error: 0.2700
# Epoch 221/1000
# 60/60 [==============================] - 0s 329us/sample - loss: 0.3862 - mean_squared_error: 0.3862 - val_loss: 0.2738 - val_mean_squared_error: 0.2738
# Epoch 222/1000
# 60/60 [==============================] - 0s 336us/sample - loss: 0.3773 - mean_squared_error: 0.3773 - val_loss: 0.2808 - val_mean_squared_error: 0.2808
# Epoch 223/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.3750 - mean_squared_error: 0.3750 - val_loss: 0.2874 - val_mean_squared_error: 0.2874
# Epoch 224/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.3738 - mean_squared_error: 0.3738 - val_loss: 0.2813 - val_mean_squared_error: 0.2813
# Epoch 225/1000
# 60/60 [==============================] - 0s 375us/sample - loss: 0.3760 - mean_squared_error: 0.3760 - val_loss: 0.2785 - val_mean_squared_error: 0.2785
# Epoch 226/1000
# 60/60 [==============================] - 0s 268us/sample - loss: 0.3732 - mean_squared_error: 0.3732 - val_loss: 0.2813 - val_mean_squared_error: 0.2813
# Epoch 227/1000
# 60/60 [==============================] - 0s 325us/sample - loss: 0.3753 - mean_squared_error: 0.3753 - val_loss: 0.2765 - val_mean_squared_error: 0.2765
# Epoch 228/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.3822 - mean_squared_error: 0.3822 - val_loss: 0.2718 - val_mean_squared_error: 0.2718
# Epoch 229/1000
# 60/60 [==============================] - 0s 298us/sample - loss: 0.3754 - mean_squared_error: 0.3754 - val_loss: 0.2838 - val_mean_squared_error: 0.2838
# Epoch 230/1000
# 60/60 [==============================] - 0s 297us/sample - loss: 0.3721 - mean_squared_error: 0.3721 - val_loss: 0.2836 - val_mean_squared_error: 0.2836
# Epoch 231/1000
# 60/60 [==============================] - 0s 375us/sample - loss: 0.3760 - mean_squared_error: 0.3760 - val_loss: 0.2784 - val_mean_squared_error: 0.2784
# Epoch 232/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.3735 - mean_squared_error: 0.3735 - val_loss: 0.2884 - val_mean_squared_error: 0.2884
# Epoch 233/1000
# 60/60 [==============================] - 0s 377us/sample - loss: 0.3779 - mean_squared_error: 0.3779 - val_loss: 0.2895 - val_mean_squared_error: 0.2895
# Epoch 234/1000
# 60/60 [==============================] - 0s 444us/sample - loss: 0.3752 - mean_squared_error: 0.3752 - val_loss: 0.2782 - val_mean_squared_error: 0.2782
# Epoch 235/1000
# 60/60 [==============================] - 0s 325us/sample - loss: 0.3707 - mean_squared_error: 0.3707 - val_loss: 0.2814 - val_mean_squared_error: 0.2814
# Epoch 236/1000
# 60/60 [==============================] - 0s 396us/sample - loss: 0.3693 - mean_squared_error: 0.3693 - val_loss: 0.2752 - val_mean_squared_error: 0.2752
# Epoch 237/1000
# 60/60 [==============================] - 0s 382us/sample - loss: 0.3699 - mean_squared_error: 0.3699 - val_loss: 0.2786 - val_mean_squared_error: 0.2786
# Epoch 238/1000
# 60/60 [==============================] - 0s 332us/sample - loss: 0.3685 - mean_squared_error: 0.3685 - val_loss: 0.2733 - val_mean_squared_error: 0.2733
# Epoch 239/1000
# 60/60 [==============================] - 0s 385us/sample - loss: 0.3734 - mean_squared_error: 0.3734 - val_loss: 0.2870 - val_mean_squared_error: 0.2870
# Epoch 240/1000
# 60/60 [==============================] - 0s 321us/sample - loss: 0.3784 - mean_squared_error: 0.3784 - val_loss: 0.2788 - val_mean_squared_error: 0.2788
# Epoch 241/1000
# 60/60 [==============================] - 0s 307us/sample - loss: 0.3830 - mean_squared_error: 0.3830 - val_loss: 0.2915 - val_mean_squared_error: 0.2915
# Epoch 242/1000
# 60/60 [==============================] - 0s 353us/sample - loss: 0.3672 - mean_squared_error: 0.3672 - val_loss: 0.2729 - val_mean_squared_error: 0.2729
# Epoch 243/1000
# 60/60 [==============================] - 0s 284us/sample - loss: 0.3899 - mean_squared_error: 0.3899 - val_loss: 0.2723 - val_mean_squared_error: 0.2723
# Epoch 244/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.3630 - mean_squared_error: 0.3630 - val_loss: 0.2741 - val_mean_squared_error: 0.2741
# Epoch 245/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.3640 - mean_squared_error: 0.3640 - val_loss: 0.2756 - val_mean_squared_error: 0.2756
# Epoch 246/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.3705 - mean_squared_error: 0.3705 - val_loss: 0.2663 - val_mean_squared_error: 0.2663
# Epoch 247/1000
# 60/60 [==============================] - 0s 270us/sample - loss: 0.3649 - mean_squared_error: 0.3649 - val_loss: 0.2687 - val_mean_squared_error: 0.2687
# Epoch 248/1000
# 60/60 [==============================] - 0s 482us/sample - loss: 0.3745 - mean_squared_error: 0.3745 - val_loss: 0.2770 - val_mean_squared_error: 0.2770
# Epoch 249/1000
# 60/60 [==============================] - 0s 334us/sample - loss: 0.3791 - mean_squared_error: 0.3791 - val_loss: 0.2644 - val_mean_squared_error: 0.2644
# Epoch 250/1000
# 60/60 [==============================] - 0s 307us/sample - loss: 0.3771 - mean_squared_error: 0.3771 - val_loss: 0.2854 - val_mean_squared_error: 0.2854
# Epoch 251/1000
# 60/60 [==============================] - 0s 303us/sample - loss: 0.3657 - mean_squared_error: 0.3657 - val_loss: 0.2697 - val_mean_squared_error: 0.2697
# Epoch 252/1000
# 60/60 [==============================] - 0s 395us/sample - loss: 0.3638 - mean_squared_error: 0.3638 - val_loss: 0.2677 - val_mean_squared_error: 0.2677
# Epoch 253/1000
# 60/60 [==============================] - 0s 357us/sample - loss: 0.3695 - mean_squared_error: 0.3695 - val_loss: 0.2671 - val_mean_squared_error: 0.2671
# Epoch 254/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.3624 - mean_squared_error: 0.3624 - val_loss: 0.2784 - val_mean_squared_error: 0.2784
# Epoch 255/1000
# 60/60 [==============================] - 0s 309us/sample - loss: 0.3793 - mean_squared_error: 0.3793 - val_loss: 0.2767 - val_mean_squared_error: 0.2767
# Epoch 256/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.3712 - mean_squared_error: 0.3712 - val_loss: 0.2661 - val_mean_squared_error: 0.2661
# Epoch 257/1000
# 60/60 [==============================] - 0s 353us/sample - loss: 0.3583 - mean_squared_error: 0.3583 - val_loss: 0.2726 - val_mean_squared_error: 0.2726
# Epoch 258/1000
# 60/60 [==============================] - 0s 376us/sample - loss: 0.3576 - mean_squared_error: 0.3576 - val_loss: 0.2770 - val_mean_squared_error: 0.2770
# Epoch 259/1000
# 60/60 [==============================] - 0s 358us/sample - loss: 0.3571 - mean_squared_error: 0.3571 - val_loss: 0.2718 - val_mean_squared_error: 0.2718
# Epoch 260/1000
# 60/60 [==============================] - 0s 288us/sample - loss: 0.3600 - mean_squared_error: 0.3600 - val_loss: 0.2800 - val_mean_squared_error: 0.2800
# Epoch 261/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.3595 - mean_squared_error: 0.3595 - val_loss: 0.2718 - val_mean_squared_error: 0.2718
# Epoch 262/1000
# 60/60 [==============================] - 0s 336us/sample - loss: 0.3559 - mean_squared_error: 0.3559 - val_loss: 0.2732 - val_mean_squared_error: 0.2732
# Epoch 263/1000
# 60/60 [==============================] - 0s 376us/sample - loss: 0.3647 - mean_squared_error: 0.3647 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 264/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.3557 - mean_squared_error: 0.3557 - val_loss: 0.2711 - val_mean_squared_error: 0.2711
# Epoch 265/1000
# 60/60 [==============================] - 0s 377us/sample - loss: 0.3576 - mean_squared_error: 0.3576 - val_loss: 0.2786 - val_mean_squared_error: 0.2786
# Epoch 266/1000
# 60/60 [==============================] - 0s 320us/sample - loss: 0.3572 - mean_squared_error: 0.3572 - val_loss: 0.2666 - val_mean_squared_error: 0.2666
# Epoch 267/1000
# 60/60 [==============================] - 0s 337us/sample - loss: 0.3554 - mean_squared_error: 0.3554 - val_loss: 0.2686 - val_mean_squared_error: 0.2686
# Epoch 268/1000
# 60/60 [==============================] - 0s 292us/sample - loss: 0.3527 - mean_squared_error: 0.3527 - val_loss: 0.2650 - val_mean_squared_error: 0.2650
# Epoch 269/1000
# 60/60 [==============================] - 0s 311us/sample - loss: 0.3617 - mean_squared_error: 0.3617 - val_loss: 0.2860 - val_mean_squared_error: 0.2860
# Epoch 270/1000
# 60/60 [==============================] - 0s 333us/sample - loss: 0.3532 - mean_squared_error: 0.3532 - val_loss: 0.2730 - val_mean_squared_error: 0.2730
# Epoch 271/1000
# 60/60 [==============================] - 0s 319us/sample - loss: 0.3506 - mean_squared_error: 0.3506 - val_loss: 0.2672 - val_mean_squared_error: 0.2672
# Epoch 272/1000
# 60/60 [==============================] - 0s 310us/sample - loss: 0.3739 - mean_squared_error: 0.3739 - val_loss: 0.2653 - val_mean_squared_error: 0.2653
# Epoch 273/1000
# 60/60 [==============================] - 0s 431us/sample - loss: 0.3547 - mean_squared_error: 0.3547 - val_loss: 0.2577 - val_mean_squared_error: 0.2577
# Epoch 274/1000
# 60/60 [==============================] - 0s 361us/sample - loss: 0.3564 - mean_squared_error: 0.3564 - val_loss: 0.2641 - val_mean_squared_error: 0.2641
# Epoch 275/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.3658 - mean_squared_error: 0.3658 - val_loss: 0.2912 - val_mean_squared_error: 0.2912
# Epoch 276/1000
# 60/60 [==============================] - 0s 328us/sample - loss: 0.3512 - mean_squared_error: 0.3512 - val_loss: 0.2697 - val_mean_squared_error: 0.2697
# Epoch 277/1000
# 60/60 [==============================] - 0s 352us/sample - loss: 0.3542 - mean_squared_error: 0.3542 - val_loss: 0.2782 - val_mean_squared_error: 0.2782
# Epoch 278/1000
# 60/60 [==============================] - 0s 311us/sample - loss: 0.3476 - mean_squared_error: 0.3476 - val_loss: 0.2655 - val_mean_squared_error: 0.2655
# Epoch 279/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.3480 - mean_squared_error: 0.3480 - val_loss: 0.2675 - val_mean_squared_error: 0.2675
# Epoch 280/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.3461 - mean_squared_error: 0.3461 - val_loss: 0.2663 - val_mean_squared_error: 0.2663
# Epoch 281/1000
# 60/60 [==============================] - 0s 307us/sample - loss: 0.3444 - mean_squared_error: 0.3444 - val_loss: 0.2646 - val_mean_squared_error: 0.2646
# Epoch 282/1000
# ...
# Epoch 906/1000
# 60/60 [==============================] - 0s 383us/sample - loss: 0.0940 - mean_squared_error: 0.0940 - val_loss: 0.1542 - val_mean_squared_error: 0.1542
# Epoch 907/1000
# 60/60 [==============================] - 0s 399us/sample - loss: 0.0906 - mean_squared_error: 0.0906 - val_loss: 0.1559 - val_mean_squared_error: 0.1559
# Epoch 908/1000
# 60/60 [==============================] - 0s 395us/sample - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.1538 - val_mean_squared_error: 0.1538
# Epoch 909/1000
# 60/60 [==============================] - 0s 471us/sample - loss: 0.0922 - mean_squared_error: 0.0922 - val_loss: 0.1748 - val_mean_squared_error: 0.1748
# Epoch 910/1000
# 60/60 [==============================] - 0s 427us/sample - loss: 0.1041 - mean_squared_error: 0.1041 - val_loss: 0.1701 - val_mean_squared_error: 0.1701
# Epoch 911/1000
# 60/60 [==============================] - 0s 399us/sample - loss: 0.0972 - mean_squared_error: 0.0972 - val_loss: 0.1588 - val_mean_squared_error: 0.1588
# Epoch 912/1000
# 60/60 [==============================] - 0s 539us/sample - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.1550 - val_mean_squared_error: 0.1550
# Epoch 913/1000
# 60/60 [==============================] - 0s 389us/sample - loss: 0.1131 - mean_squared_error: 0.1131 - val_loss: 0.1686 - val_mean_squared_error: 0.1686
# Epoch 914/1000
# 60/60 [==============================] - 0s 497us/sample - loss: 0.1002 - mean_squared_error: 0.1002 - val_loss: 0.1611 - val_mean_squared_error: 0.1611
# Epoch 915/1000
# 60/60 [==============================] - 0s 480us/sample - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1812 - val_mean_squared_error: 0.1812
# Epoch 916/1000
# 60/60 [==============================] - 0s 405us/sample - loss: 0.1000 - mean_squared_error: 0.1000 - val_loss: 0.1563 - val_mean_squared_error: 0.1563
# Epoch 917/1000
# 60/60 [==============================] - 0s 433us/sample - loss: 0.0900 - mean_squared_error: 0.0900 - val_loss: 0.1531 - val_mean_squared_error: 0.1531
# Epoch 918/1000
# 60/60 [==============================] - 0s 420us/sample - loss: 0.0960 - mean_squared_error: 0.0960 - val_loss: 0.1564 - val_mean_squared_error: 0.1564
# Epoch 919/1000
# 60/60 [==============================] - 0s 416us/sample - loss: 0.1059 - mean_squared_error: 0.1059 - val_loss: 0.1728 - val_mean_squared_error: 0.1728
# Epoch 920/1000
# 60/60 [==============================] - 0s 425us/sample - loss: 0.0989 - mean_squared_error: 0.0989 - val_loss: 0.1558 - val_mean_squared_error: 0.1558
# Epoch 921/1000
# 60/60 [==============================] - 0s 405us/sample - loss: 0.0913 - mean_squared_error: 0.0913 - val_loss: 0.1553 - val_mean_squared_error: 0.1553
# Epoch 922/1000
# 60/60 [==============================] - 0s 392us/sample - loss: 0.0900 - mean_squared_error: 0.0900 - val_loss: 0.1523 - val_mean_squared_error: 0.1523
# Epoch 923/1000
# 60/60 [==============================] - 0s 420us/sample - loss: 0.0962 - mean_squared_error: 0.0962 - val_loss: 0.1603 - val_mean_squared_error: 0.1603
# Epoch 924/1000
# 60/60 [==============================] - 0s 359us/sample - loss: 0.0958 - mean_squared_error: 0.0958 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 925/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.0988 - mean_squared_error: 0.0988 - val_loss: 0.1536 - val_mean_squared_error: 0.1536
# Epoch 926/1000
# 60/60 [==============================] - 0s 365us/sample - loss: 0.0940 - mean_squared_error: 0.0940 - val_loss: 0.1651 - val_mean_squared_error: 0.1651
# Epoch 927/1000
# 60/60 [==============================] - 0s 468us/sample - loss: 0.1477 - mean_squared_error: 0.1477 - val_loss: 0.1815 - val_mean_squared_error: 0.1815
# Epoch 928/1000
# 60/60 [==============================] - 0s 463us/sample - loss: 0.1092 - mean_squared_error: 0.1092 - val_loss: 0.1534 - val_mean_squared_error: 0.1534
# Epoch 929/1000
# 60/60 [==============================] - 0s 389us/sample - loss: 0.0910 - mean_squared_error: 0.0910 - val_loss: 0.1540 - val_mean_squared_error: 0.1540
# Epoch 930/1000
# 60/60 [==============================] - 0s 376us/sample - loss: 0.1301 - mean_squared_error: 0.1301 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 931/1000
# 60/60 [==============================] - 0s 505us/sample - loss: 0.0910 - mean_squared_error: 0.0910 - val_loss: 0.1499 - val_mean_squared_error: 0.1499
# Epoch 932/1000
# 60/60 [==============================] - 0s 493us/sample - loss: 0.0924 - mean_squared_error: 0.0924 - val_loss: 0.1502 - val_mean_squared_error: 0.1502
# Epoch 933/1000
# 60/60 [==============================] - 0s 365us/sample - loss: 0.0892 - mean_squared_error: 0.0892 - val_loss: 0.1520 - val_mean_squared_error: 0.1520
# Epoch 934/1000
# 60/60 [==============================] - 0s 347us/sample - loss: 0.0905 - mean_squared_error: 0.0905 - val_loss: 0.1524 - val_mean_squared_error: 0.1524
# Epoch 935/1000
# 60/60 [==============================] - 0s 606us/sample - loss: 0.0874 - mean_squared_error: 0.0874 - val_loss: 0.1544 - val_mean_squared_error: 0.1544
# Epoch 936/1000
# 60/60 [==============================] - 0s 429us/sample - loss: 0.0894 - mean_squared_error: 0.0894 - val_loss: 0.1512 - val_mean_squared_error: 0.1512
# Epoch 937/1000
# 60/60 [==============================] - 0s 413us/sample - loss: 0.0997 - mean_squared_error: 0.0997 - val_loss: 0.1587 - val_mean_squared_error: 0.1587
# Epoch 938/1000
# 60/60 [==============================] - 0s 353us/sample - loss: 0.0966 - mean_squared_error: 0.0966 - val_loss: 0.1569 - val_mean_squared_error: 0.1569
# Epoch 939/1000
# 60/60 [==============================] - 0s 479us/sample - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.1581 - val_mean_squared_error: 0.1581
# Epoch 940/1000
# 60/60 [==============================] - 0s 469us/sample - loss: 0.0933 - mean_squared_error: 0.0933 - val_loss: 0.1611 - val_mean_squared_error: 0.1611
# Epoch 941/1000
# 60/60 [==============================] - 0s 488us/sample - loss: 0.0963 - mean_squared_error: 0.0963 - val_loss: 0.1512 - val_mean_squared_error: 0.1512
# Epoch 942/1000
# 60/60 [==============================] - 0s 452us/sample - loss: 0.0886 - mean_squared_error: 0.0886 - val_loss: 0.1543 - val_mean_squared_error: 0.1543
# Epoch 943/1000
# 60/60 [==============================] - 0s 636us/sample - loss: 0.0885 - mean_squared_error: 0.0885 - val_loss: 0.1499 - val_mean_squared_error: 0.1499
# Epoch 944/1000
# 60/60 [==============================] - 0s 595us/sample - loss: 0.0913 - mean_squared_error: 0.0913 - val_loss: 0.1566 - val_mean_squared_error: 0.1566
# Epoch 945/1000
# 60/60 [==============================] - 0s 351us/sample - loss: 0.0920 - mean_squared_error: 0.0920 - val_loss: 0.1585 - val_mean_squared_error: 0.1585
# Epoch 946/1000
# 60/60 [==============================] - 0s 405us/sample - loss: 0.0942 - mean_squared_error: 0.0942 - val_loss: 0.1487 - val_mean_squared_error: 0.1487
# Epoch 947/1000
# 60/60 [==============================] - 0s 380us/sample - loss: 0.0877 - mean_squared_error: 0.0877 - val_loss: 0.1504 - val_mean_squared_error: 0.1504
# Epoch 948/1000
# 60/60 [==============================] - 0s 388us/sample - loss: 0.1008 - mean_squared_error: 0.1008 - val_loss: 0.1558 - val_mean_squared_error: 0.1558
# Epoch 949/1000
# 60/60 [==============================] - 0s 397us/sample - loss: 0.0907 - mean_squared_error: 0.0907 - val_loss: 0.1526 - val_mean_squared_error: 0.1526
# Epoch 950/1000
# 60/60 [==============================] - 0s 362us/sample - loss: 0.0867 - mean_squared_error: 0.0867 - val_loss: 0.1545 - val_mean_squared_error: 0.1545
# Epoch 951/1000
# 60/60 [==============================] - 0s 356us/sample - loss: 0.0911 - mean_squared_error: 0.0911 - val_loss: 0.1558 - val_mean_squared_error: 0.1558
# Epoch 952/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.0989 - mean_squared_error: 0.0989 - val_loss: 0.1578 - val_mean_squared_error: 0.1578
# Epoch 953/1000
# 60/60 [==============================] - 0s 604us/sample - loss: 0.0917 - mean_squared_error: 0.0917 - val_loss: 0.1510 - val_mean_squared_error: 0.1510
# Epoch 954/1000
# 60/60 [==============================] - 0s 509us/sample - loss: 0.0852 - mean_squared_error: 0.0852 - val_loss: 0.1608 - val_mean_squared_error: 0.1608
# Epoch 955/1000
# 60/60 [==============================] - 0s 475us/sample - loss: 0.1044 - mean_squared_error: 0.1044 - val_loss: 0.1482 - val_mean_squared_error: 0.1482
# Epoch 956/1000
# 60/60 [==============================] - 0s 413us/sample - loss: 0.0877 - mean_squared_error: 0.0877 - val_loss: 0.1521 - val_mean_squared_error: 0.1521
# Epoch 957/1000
# 60/60 [==============================] - 0s 500us/sample - loss: 0.0843 - mean_squared_error: 0.0843 - val_loss: 0.1537 - val_mean_squared_error: 0.1537
# Epoch 958/1000
# 60/60 [==============================] - 0s 407us/sample - loss: 0.1180 - mean_squared_error: 0.1180 - val_loss: 0.1535 - val_mean_squared_error: 0.1535
# Epoch 959/1000
# 60/60 [==============================] - 0s 366us/sample - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.1487 - val_mean_squared_error: 0.1487
# Epoch 960/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.0901 - mean_squared_error: 0.0901 - val_loss: 0.1508 - val_mean_squared_error: 0.1508
# Epoch 961/1000
# 60/60 [==============================] - 0s 438us/sample - loss: 0.0900 - mean_squared_error: 0.0900 - val_loss: 0.1528 - val_mean_squared_error: 0.1528
# Epoch 962/1000
# 60/60 [==============================] - 0s 559us/sample - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.1576 - val_mean_squared_error: 0.1576
# Epoch 963/1000
# 60/60 [==============================] - 0s 343us/sample - loss: 0.0950 - mean_squared_error: 0.0950 - val_loss: 0.1506 - val_mean_squared_error: 0.1506
# Epoch 964/1000
# 60/60 [==============================] - 0s 360us/sample - loss: 0.0889 - mean_squared_error: 0.0889 - val_loss: 0.1484 - val_mean_squared_error: 0.1484
# Epoch 965/1000
# 60/60 [==============================] - 0s 410us/sample - loss: 0.1089 - mean_squared_error: 0.1089 - val_loss: 0.1467 - val_mean_squared_error: 0.1467
# Epoch 966/1000
# 60/60 [==============================] - 0s 417us/sample - loss: 0.0870 - mean_squared_error: 0.0870 - val_loss: 0.1502 - val_mean_squared_error: 0.1502
# Epoch 967/1000
# 60/60 [==============================] - 0s 407us/sample - loss: 0.0874 - mean_squared_error: 0.0874 - val_loss: 0.1482 - val_mean_squared_error: 0.1482
# Epoch 968/1000
# 60/60 [==============================] - 0s 361us/sample - loss: 0.0847 - mean_squared_error: 0.0847 - val_loss: 0.1474 - val_mean_squared_error: 0.1474
# Epoch 969/1000
# 60/60 [==============================] - 0s 363us/sample - loss: 0.0911 - mean_squared_error: 0.0911 - val_loss: 0.1472 - val_mean_squared_error: 0.1472
# Epoch 970/1000
# 60/60 [==============================] - 0s 413us/sample - loss: 0.0870 - mean_squared_error: 0.0870 - val_loss: 0.1520 - val_mean_squared_error: 0.1520
# Epoch 971/1000
# 60/60 [==============================] - 0s 418us/sample - loss: 0.0865 - mean_squared_error: 0.0865 - val_loss: 0.1489 - val_mean_squared_error: 0.1489
# Epoch 972/1000
# 60/60 [==============================] - 0s 431us/sample - loss: 0.0851 - mean_squared_error: 0.0851 - val_loss: 0.1584 - val_mean_squared_error: 0.1584
# Epoch 973/1000
# 60/60 [==============================] - 0s 389us/sample - loss: 0.0892 - mean_squared_error: 0.0892 - val_loss: 0.1681 - val_mean_squared_error: 0.1681
# Epoch 974/1000
# 60/60 [==============================] - 0s 387us/sample - loss: 0.0874 - mean_squared_error: 0.0874 - val_loss: 0.1487 - val_mean_squared_error: 0.1487
# Epoch 975/1000
# 60/60 [==============================] - 0s 404us/sample - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.1558 - val_mean_squared_error: 0.1558
# Epoch 976/1000
# 60/60 [==============================] - 0s 579us/sample - loss: 0.0903 - mean_squared_error: 0.0903 - val_loss: 0.1540 - val_mean_squared_error: 0.1540
# Epoch 977/1000
# 60/60 [==============================] - 0s 415us/sample - loss: 0.0871 - mean_squared_error: 0.0871 - val_loss: 0.1487 - val_mean_squared_error: 0.1487
# Epoch 978/1000
# 60/60 [==============================] - 0s 382us/sample - loss: 0.0871 - mean_squared_error: 0.0871 - val_loss: 0.1550 - val_mean_squared_error: 0.1550
# Epoch 979/1000
# 60/60 [==============================] - 0s 411us/sample - loss: 0.0876 - mean_squared_error: 0.0876 - val_loss: 0.1489 - val_mean_squared_error: 0.1489
# Epoch 980/1000
# 60/60 [==============================] - 0s 410us/sample - loss: 0.0838 - mean_squared_error: 0.0838 - val_loss: 0.1482 - val_mean_squared_error: 0.1482
# Epoch 981/1000
# 60/60 [==============================] - 0s 381us/sample - loss: 0.0898 - mean_squared_error: 0.0898 - val_loss: 0.1502 - val_mean_squared_error: 0.1502
# Epoch 982/1000
# 60/60 [==============================] - 0s 437us/sample - loss: 0.1117 - mean_squared_error: 0.1117 - val_loss: 0.1482 - val_mean_squared_error: 0.1482
# Epoch 983/1000
# 60/60 [==============================] - 0s 426us/sample - loss: 0.0841 - mean_squared_error: 0.0841 - val_loss: 0.1469 - val_mean_squared_error: 0.1469
# Epoch 984/1000
# 60/60 [==============================] - 0s 446us/sample - loss: 0.0984 - mean_squared_error: 0.0984 - val_loss: 0.1464 - val_mean_squared_error: 0.1464
# Epoch 985/1000
# 60/60 [==============================] - 0s 460us/sample - loss: 0.0992 - mean_squared_error: 0.0992 - val_loss: 0.1528 - val_mean_squared_error: 0.1528
# Epoch 986/1000
# 60/60 [==============================] - 0s 481us/sample - loss: 0.0938 - mean_squared_error: 0.0938 - val_loss: 0.1459 - val_mean_squared_error: 0.1459
# Epoch 987/1000
# 60/60 [==============================] - 0s 358us/sample - loss: 0.0885 - mean_squared_error: 0.0885 - val_loss: 0.1466 - val_mean_squared_error: 0.1466
# Epoch 988/1000
# 60/60 [==============================] - 0s 425us/sample - loss: 0.0921 - mean_squared_error: 0.0921 - val_loss: 0.1615 - val_mean_squared_error: 0.1615
# Epoch 989/1000
# 60/60 [==============================] - 0s 392us/sample - loss: 0.0911 - mean_squared_error: 0.0911 - val_loss: 0.1513 - val_mean_squared_error: 0.1513
# Epoch 990/1000
# 60/60 [==============================] - 0s 365us/sample - loss: 0.0863 - mean_squared_error: 0.0863 - val_loss: 0.1483 - val_mean_squared_error: 0.1483
# Epoch 991/1000
# 60/60 [==============================] - 0s 412us/sample - loss: 0.0851 - mean_squared_error: 0.0851 - val_loss: 0.1461 - val_mean_squared_error: 0.1461
# Epoch 992/1000
# 60/60 [==============================] - 0s 413us/sample - loss: 0.0868 - mean_squared_error: 0.0868 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 993/1000
# 60/60 [==============================] - 0s 445us/sample - loss: 0.0866 - mean_squared_error: 0.0866 - val_loss: 0.1476 - val_mean_squared_error: 0.1476
# Epoch 994/1000
# 60/60 [==============================] - 0s 557us/sample - loss: 0.0824 - mean_squared_error: 0.0824 - val_loss: 0.1461 - val_mean_squared_error: 0.1461
# Epoch 995/1000
# 60/60 [==============================] - 0s 371us/sample - loss: 0.0851 - mean_squared_error: 0.0851 - val_loss: 0.1480 - val_mean_squared_error: 0.1480
# Epoch 996/1000
# 60/60 [==============================] - 0s 349us/sample - loss: 0.1053 - mean_squared_error: 0.1053 - val_loss: 0.1511 - val_mean_squared_error: 0.1511
# Epoch 997/1000
# 60/60 [==============================] - 0s 383us/sample - loss: 0.0864 - mean_squared_error: 0.0864 - val_loss: 0.1502 - val_mean_squared_error: 0.1502
# Epoch 998/1000
# 60/60 [==============================] - 0s 542us/sample - loss: 0.1033 - mean_squared_error: 0.1033 - val_loss: 0.1719 - val_mean_squared_error: 0.1719
# Epoch 999/1000
# 60/60 [==============================] - 0s 438us/sample - loss: 0.0997 - mean_squared_error: 0.0997 - val_loss: 0.1512 - val_mean_squared_error: 0.1512
# Epoch 1000/1000
# 60/60 [==============================] - 0s 372us/sample - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.1461 - val_mean_squared_error: 0.1461
# elapsed : 30.43185567855835

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20, validation_split=0.1)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_103 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_104 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 12.00013780593872

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %%
# (train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.0001)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=5, verbose=2, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_106 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_107 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_108 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 - 6s - loss: 0.2406 - mean_squared_error: 0.2406
# Epoch 2/5
# 60000/60000 - 6s - loss: 0.1140 - mean_squared_error: 0.1140
# Epoch 3/5
# 60000/60000 - 6s - loss: 0.0939 - mean_squared_error: 0.0939
# Epoch 4/5
# 60000/60000 - 6s - loss: 0.0657 - mean_squared_error: 0.0657
# Epoch 5/5
# 60000/60000 - 6s - loss: 0.0400 - mean_squared_error: 0.0400
# elapsed : 29.296075105667114

# %%
y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_109 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_110 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_111 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.8745334148406982

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20, shuffle=True)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_112 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_113 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_114 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.745748519897461

# %%
x = np.arange(0,10,0.1)
# np.random.shuffle(x) # COMMENTED
y = np.sin(x)

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_115 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_116 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_117 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 1.2792062759399414

# %%
x = np.arange(0,10,0.1)
np.random.shuffle(x) # UNCOMMENT
y = np.sin(x)

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=-10, end=10, step=0.1)

print("min=",np.min(train_x))
print("max=",np.max(train_x))

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# min= -9.700000000000001
# max= 9.899999999999928

# %%
min = -10 # ADDED
max = 10 # ADDED

train_x = (train_x-min)/(max-min) # ADDED
test_x = (test_x-min)/(max-min) # ADDED

print("min=",np.min(train_x))
print("max=",np.max(train_x))

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# min= 0.014999999999999947
# max= 0.9949999999999963

# %%
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_118 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_119 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_120 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 13.653894901275635
# 80/80 [==============================] - 0s 2ms/sample - loss: 0.5767 - mean_squared_error: 0.5767
# loss= 0.5766593456268311
# mse= 0.5766593

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_121 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_122 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_123 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 8.286107778549194
# 40/40 [==============================] - 0s 3ms/sample - loss: 0.1480 - mean_squared_error: 0.1480
# loss= 0.14796775877475737
# mse= 0.14796776

# %%
model.save('my_model.h5')

# !ls -al
# Out:
# total 60
# drwxr-xr-x 1 root root  4096 Aug  5 11:13 .
# drwxr-xr-x 1 root root  4096 Aug  5 08:58 ..
# -rw-r--r-- 1 root root 12360 Aug  5 09:07 base_result.png
# drwxr-xr-x 4 root root  4096 Jul 16 13:19 .config
# drwxr-xr-x 4 root root  4096 Aug  5 11:13 model_path
# -rw-r--r-- 1 root root 20840 Aug  5 11:15 my_model.h5
# drwxr-xr-x 1 root root  4096 Jul 16 13:20 sample_data

# %%
new_model = keras.models.load_model('my_model.h5')

y_ = new_model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-9e3381b1bcb8> in <module>()
# ----> 1 new_model = keras.models.load_model('my_model.h5')
#       2
#       3 y_ = new_model.predict(test_x)
#       4
#       5 plt.scatter(test_x,test_y)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     141   if (h5py is not None and (
#     142       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 143     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     144
#     145   if isinstance(filepath, six.string_types):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     158     if model_config is None:
#     159       raise ValueError('No model found in config file.')
# --> 160     model_config = json.loads(model_config.decode('utf-8'))
#     161     model = model_config_lib.model_from_config(model_config,
#     162                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
# keras.experimental.export_saved_model(model, 'model_path')   ---> deprecated
keras.models.save_model(model, 'model_path', save_format='tf')
# model.save('model_path', save_format="tf")

# !ls -al
# !ls -al model_path

# new_model = keras.experimental.load_from_saved_model('model_path')   ---> deprecated
new_model = keras.models.load_model('model_path')

y_ = new_model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eb30290> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eb30290> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eaf7560> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eaf7560> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53ea99710> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53ea99710> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eab4830> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eab4830> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eab00e0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eab00e0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eb6c5f0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53eb6c5f0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc540465950> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc540465950> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53ead8b00> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc53ead8b00> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc5404a7710> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc5404a7710> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <function canonicalize_signatures.<locals>.signature_wrapper at 0x7fc53eb30950> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <function canonicalize_signatures.<locals>.signature_wrapper at 0x7fc53eb30950> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc542eb8e60> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fc542eb8e60> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Index'
# INFO:tensorflow:Assets written to: model_path/assets
# total 60
# drwxr-xr-x 1 root root  4096 Aug  5 11:13 .
# drwxr-xr-x 1 root root  4096 Aug  5 08:58 ..
# -rw-r--r-- 1 root root 12360 Aug  5 09:07 base_result.png
# drwxr-xr-x 4 root root  4096 Jul 16 13:19 .config
# drwxr-xr-x 4 root root  4096 Aug  5 11:32 model_path
# -rw-r--r-- 1 root root 20840 Aug  5 11:15 my_model.h5
# drwxr-xr-x 1 root root  4096 Jul 16 13:20 sample_data
# total 92
# drwxr-xr-x 4 root root  4096 Aug  5 11:32 .
# drwxr-xr-x 1 root root  4096 Aug  5 11:13 ..
# drwxr-xr-x 2 root root  4096 Aug  5 11:13 assets
# -rw-r--r-- 1 root root 75292 Aug  5 11:32 saved_model.pb
# drwxr-xr-x 2 root root  4096 Aug  5 11:32 variables

# %%
from tensorflow.python.client import device_lib
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)

# %%
with tf.device('/device:GPU:0'): # ADDED

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_124 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_125 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_126 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.501429080963135

# %%
# with tf.device('/device:GPU:0'):
with tf.device('/GPU:0'):

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_127 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_128 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_129 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.337092161178589

# %%
# with tf.device('/GPU:0'):
with tf.device('/gpu:0'):

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_130 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_131 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_132 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.464360475540161

# %%
# with tf.device('/GPU:0'):
with tf.device('/gpu'):

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_133 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_134 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_135 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.321925401687622

# %%
# with tf.device('/GPU:0'):
with tf.device('/CPU:0'):

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_136 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_137 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_138 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.2513136863708496

# %%
# with tf.device('/GPU:0'):
with tf.device('/CPU'):

  model = Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_139 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_140 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_141 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.387540340423584

# %%
from tensorflow.keras.layers import Dropout

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dropout(0.1)) # ADDED
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_142 (Dense)            (None, 10)                20
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_143 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_144 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.389776468276978
# 40/40 [==============================] - 0s 5ms/sample - loss: 0.1950 - mean_squared_error: 0.1950
# loss= 0.1950133740901947
# mse= 0.19501337

# %%
from tensorflow.keras.layers import BatchNormalization

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(BatchNormalization()) # ADDED
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_145 (Dense)            (None, 10)                20
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10)                40
# _________________________________________________________________
# dense_146 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_147 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 181
# Trainable params: 161
# Non-trainable params: 20
# _________________________________________________________________
# elapsed : 11.227219820022583
# 40/40 [==============================] - 0s 4ms/sample - loss: 0.0312 - mean_squared_error: 0.0312
# loss= 0.031227563321590424
# mse= 0.031227564

# %%
from tensorflow.keras.regularizers import l1, l2

(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh', input_shape=(1,), kernel_regularizer=l2(0.001)))
model.add(Dense(10, activation='tanh', kernel_regularizer=l2(0.001)))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_148 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_149 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_150 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.246105194091797
# 40/40 [==============================] - 0s 5ms/sample - loss: 0.2285 - mean_squared_error: 0.2128
# loss= 0.22852177619934083
# mse= 0.21280845

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh', input_shape=(1,), kernel_initializer='he_normal'))
model.add(Dense(10, activation='tanh', kernel_initializer='he_normal'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_151 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_152 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_153 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.525627374649048
# 40/40 [==============================] - 0s 5ms/sample - loss: 0.1424 - mean_squared_error: 0.1424
# loss= 0.14238484501838683
# mse= 0.14238484

# %%
def train_sin_with_noise(noise_size):

  # x = np.arange(0,10,0.1)
  x = np.arange(0,10,0.001)
  np.random.shuffle(x)
  y = np.sin(x)

  noiseless_y = np.copy(y) # ADD
  y = y + np.random.rand(y.shape[0])*noise_size - noise_size/2.0 # ADD

  split_index = int(x.shape[0]*0.6)

  train_x, test_x = x[:split_index], x[split_index:]
  train_y, test_y = y[:split_index], y[split_index:]
  test_noiseless_y = noiseless_y[split_index:] # ADD

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()


  start_time = time.time()
  model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=100)
  print("elapsed : {}".format(time.time() - start_time))    


  loss, mse = model.evaluate(test_x, test_y)
  print("loss=",loss)
  print("mse=",mse)


  y_ = model.predict(test_x)

  # plt.scatter(test_x,test_y)
  plt.scatter(test_x,test_y, s=1)
  plt.scatter(test_x,y_, s=1)
  plt.show()

# %%
train_sin_with_noise(0.0)
# Out:
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_154 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_155 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_156 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 126.1230571269989
# 4000/4000 [==============================] - 0s 92us/sample - loss: 1.5253e-04 - mean_squared_error: 1.5253e-04
# loss= 0.0001525316535262391
# mse= 0.00015253162

# %%
train_sin_with_noise(0.1)
# Out:
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_157 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_158 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_159 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 126.7765519618988
# 4000/4000 [==============================] - 0s 111us/sample - loss: 0.0010 - mean_squared_error: 0.0010
# loss= 0.001037784829735756
# mse= 0.0010377849

# %%
train_sin_with_noise(0.5)
# Out:
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_160 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_161 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_162 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 124.90661859512329
# 4000/4000 [==============================] - 0s 104us/sample - loss: 0.0207 - mean_squared_error: 0.0207
# loss= 0.020699772208929063
# mse= 0.020699771

# %%
train_sin_with_noise(1.0)
# Out:
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_163 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_164 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_165 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 126.78291749954224
# 4000/4000 [==============================] - 0s 97us/sample - loss: 0.1027 - mean_squared_error: 0.1027
# loss= 0.10267289361357688
# mse= 0.102672905

# %%
train_sin_with_noise(10.0)
# Out:
# Model: "sequential_53"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_166 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_167 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_168 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 131.10068368911743
# 4000/4000 [==============================] - 0s 113us/sample - loss: 8.5224 - mean_squared_error: 8.5224
# loss= 8.522355434417724
# mse= 8.522354

# %%
x = np.arange(0,10,1.0)
np.random.shuffle(x)

y = np.zeros((x.shape[0],2))
y[:,0] = np.sin(x)
y[:,1] = np.random.rand(x.shape[0])

# %%
# x = np.arange(0,10,0.001)
x = np.zeros((10000,2))
x[:,0] = np.arange(0,10,0.001) # ADD
x[:,1] = np.random.rand(x.shape[0]) # ADD
np.random.shuffle(x)

# y = np.sin(x)
y = np.sin(x[:,0])

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
model.fit(train_x, train_y, epochs=100, verbose=1, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x[:,0],test_y)
plt.scatter(test_x[:,0],y_,color='r')
plt.show()
# Out:
# Model: "sequential_54"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_169 (Dense)            (None, 10)                30
# _________________________________________________________________
# dense_170 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_171 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6000 samples
# Epoch 1/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 0.3697 - mean_squared_error: 0.3697
# Epoch 2/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.3180 - mean_squared_error: 0.3180
# Epoch 3/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.2781 - mean_squared_error: 0.2781
# Epoch 4/100
# 6000/6000 [==============================] - 1s 117us/sample - loss: 0.2417 - mean_squared_error: 0.2417
# Epoch 5/100
# 6000/6000 [==============================] - 1s 117us/sample - loss: 0.2157 - mean_squared_error: 0.2157
# Epoch 6/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.1974 - mean_squared_error: 0.1974
# Epoch 7/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.1799 - mean_squared_error: 0.1799
# Epoch 8/100
# 6000/6000 [==============================] - 1s 114us/sample - loss: 0.1676 - mean_squared_error: 0.1676
# Epoch 9/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.1592 - mean_squared_error: 0.1592
# Epoch 10/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.1498 - mean_squared_error: 0.1498
# Epoch 11/100
# 6000/6000 [==============================] - 1s 112us/sample - loss: 0.1423 - mean_squared_error: 0.1423
# Epoch 12/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.1371 - mean_squared_error: 0.1371
# Epoch 13/100
# 6000/6000 [==============================] - 1s 117us/sample - loss: 0.1300 - mean_squared_error: 0.1300
# Epoch 14/100
# 6000/6000 [==============================] - 1s 118us/sample - loss: 0.1272 - mean_squared_error: 0.1272
# Epoch 15/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.1233 - mean_squared_error: 0.1233
# Epoch 16/100
# 6000/6000 [==============================] - 1s 114us/sample - loss: 0.1199 - mean_squared_error: 0.1199
# Epoch 17/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.1167 - mean_squared_error: 0.1167
# Epoch 18/100
# 6000/6000 [==============================] - 1s 114us/sample - loss: 0.1151 - mean_squared_error: 0.1151
# Epoch 19/100
# 6000/6000 [==============================] - 1s 113us/sample - loss: 0.1126 - mean_squared_error: 0.1126
# Epoch 20/100
# 6000/6000 [==============================] - 1s 113us/sample - loss: 0.1111 - mean_squared_error: 0.1111
# Epoch 21/100
# 6000/6000 [==============================] - 1s 113us/sample - loss: 0.1101 - mean_squared_error: 0.1101
# Epoch 22/100
# 6000/6000 [==============================] - 1s 110us/sample - loss: 0.1086 - mean_squared_error: 0.1086
# Epoch 23/100
# 6000/6000 [==============================] - 1s 113us/sample - loss: 0.1072 - mean_squared_error: 0.1072
# Epoch 24/100
# 6000/6000 [==============================] - 1s 114us/sample - loss: 0.1055 - mean_squared_error: 0.1055
# Epoch 25/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.1047 - mean_squared_error: 0.1047
# Epoch 26/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.1035 - mean_squared_error: 0.1035
# Epoch 27/100
# 6000/6000 [==============================] - 1s 127us/sample - loss: 0.1022 - mean_squared_error: 0.1022
# Epoch 28/100
# 6000/6000 [==============================] - 1s 121us/sample - loss: 0.1015 - mean_squared_error: 0.1015
# Epoch 29/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.1003 - mean_squared_error: 0.1003
# Epoch 30/100
# 6000/6000 [==============================] - 1s 121us/sample - loss: 0.0990 - mean_squared_error: 0.0990
# Epoch 31/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0980 - mean_squared_error: 0.0980
# Epoch 32/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0965 - mean_squared_error: 0.0965
# Epoch 33/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0951 - mean_squared_error: 0.0951
# Epoch 34/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0929 - mean_squared_error: 0.0929
# Epoch 35/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0905 - mean_squared_error: 0.0905
# Epoch 36/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0875 - mean_squared_error: 0.0875
# Epoch 37/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0846 - mean_squared_error: 0.0846
# Epoch 38/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0810 - mean_squared_error: 0.0810
# Epoch 39/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0774 - mean_squared_error: 0.0774
# Epoch 40/100
# 6000/6000 [==============================] - 1s 120us/sample - loss: 0.0746 - mean_squared_error: 0.0746
# Epoch 41/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0690 - mean_squared_error: 0.0690
# Epoch 42/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0649 - mean_squared_error: 0.0649
# Epoch 43/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0591 - mean_squared_error: 0.0591
# Epoch 44/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0526 - mean_squared_error: 0.0526
# Epoch 45/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0459 - mean_squared_error: 0.0459
# Epoch 46/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0418 - mean_squared_error: 0.0418
# Epoch 47/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0350 - mean_squared_error: 0.0350
# Epoch 48/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 49/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 50/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0182 - mean_squared_error: 0.0182
# Epoch 51/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 52/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 53/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 54/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 55/100
# 6000/6000 [==============================] - 1s 121us/sample - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 56/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 57/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 58/100
# 6000/6000 [==============================] - 1s 120us/sample - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 59/100
# 6000/6000 [==============================] - 1s 117us/sample - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 60/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 61/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 62/100
# 6000/6000 [==============================] - 1s 110us/sample - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 63/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 64/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 65/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 66/100
# 6000/6000 [==============================] - 1s 116us/sample - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 67/100
# 6000/6000 [==============================] - 1s 117us/sample - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 68/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 69/100
# 6000/6000 [==============================] - 1s 114us/sample - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 70/100
# 6000/6000 [==============================] - 1s 117us/sample - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 71/100
# 6000/6000 [==============================] - 1s 115us/sample - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 72/100
# 6000/6000 [==============================] - 1s 119us/sample - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 73/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 74/100
# 6000/6000 [==============================] - 1s 122us/sample - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 75/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 76/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 77/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 78/100
# 6000/6000 [==============================] - 1s 127us/sample - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 79/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 80/100
# 6000/6000 [==============================] - 1s 121us/sample - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 81/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 82/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 83/100
# 6000/6000 [==============================] - 1s 120us/sample - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 84/100
# 6000/6000 [==============================] - 1s 121us/sample - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 85/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 86/100
# 6000/6000 [==============================] - 1s 127us/sample - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 87/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 88/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 89/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 90/100
# 6000/6000 [==============================] - 1s 125us/sample - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 91/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 92/100
# 6000/6000 [==============================] - 1s 123us/sample - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 93/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 94/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 95/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 96/100
# 6000/6000 [==============================] - 1s 127us/sample - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 97/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 98/100
# 6000/6000 [==============================] - 1s 128us/sample - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 99/100
# 6000/6000 [==============================] - 1s 124us/sample - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 100/100
# 6000/6000 [==============================] - 1s 126us/sample - loss: 0.0034 - mean_squared_error: 0.0034
# elapsed : 74.11326599121094
# 4000/4000 [==============================] - 0s 115us/sample - loss: 7.3706e-04 - mean_squared_error: 7.3706e-04
# loss= 0.0007370648845098913
# mse= 0.0007370649

# %%
x = np.arange(0,10,0.1)
np.random.shuffle(x)
# y = np.sin(x)
y = np.random.random_sample(x.shape[0])

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]


plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback

import time

# %%
x = np.arange(-1,1,0.01)
np.random.shuffle(x)
y = x**2

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
def train_with_callbacks(callbacks):


  # 모델 정의
  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  # 모델 컴파일
  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()


  # 학습
  start_time = time.time()
  model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20, validation_split=0.1, callbacks=callbacks)
  print("elapsed : {}".format(time.time() - start_time))

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

model_check_point = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

train_with_callbacks([model_check_point])
# Out:
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_172 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_173 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_174 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 26.009175539016724

# %%
# copy from https://gist.github.com/stared/dfb4dfaf6d9a8501cd1cc8b8cb806d2e

from IPython.display import clear_output

class PlotLosses(Callback):

  def on_train_begin(self, logs={}):

    self.i = 0
    self.x = []
    self.losses = []
    self.val_losses = []

    self.fig = plt.figure()

    self.logs = []


  def on_epoch_end(self, epoch, logs={}):

    self.logs.append(logs)
    self.x.append(self.i)
    self.losses.append(logs.get('loss'))
    self.val_losses.append(logs.get('val_loss'))
    self.i += 1

    clear_output(wait=True)
    plt.plot(self.x, self.losses, label="loss")
    plt.plot(self.x, self.val_losses, label="val_loss")
    plt.legend()
    plt.show();
    print("loss = ", self.losses[-1], ", val_loss = ", self.val_losses[-1])

# %%
plot_losses = PlotLosses()

train_with_callbacks([plot_losses])
# Out:
# loss =  0.0015724672616838856 , val_loss =  0.0029491905588656664
# elapsed : 182.30791568756104

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss',  # 모니터링 대상
                               mode='auto',         # 학습 방향을 자동으로 탐지
                               patience=50)         # 중지까지의 여유분

train_with_callbacks([early_stopping])
# Out:
# Model: "sequential_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_178 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_179 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_180 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 16.762139797210693

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', # 모니터링 대상
                              factor=0.2,         # 줄이는 양
                              patience=5,         # 대상 기간동안 유지
                              min_lr=0.001)       # 최소 학습율

train_with_callbacks([reduce_lr])
# Out:
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_181 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_182 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_183 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 22.190642833709717

# %%
from sklearn.datasets import make_moons
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from matplotlib import pyplot
from pandas import DataFrame

x, y = make_moons(n_samples=100, noise=0.2, random_state=1)

df = DataFrame(dict(x=x[:,0], y=x[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

split_index = 30
train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
# copy from https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/

model = Sequential()
model.add(Dense(500, input_shape=(2,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=4000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='test_loss')
pyplot.legend()
pyplot.show()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

model = Sequential()
model.add(Dense(500, input_shape=(2,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


model_check_point = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
plot_losses = PlotLosses()
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

callbacks = [model_check_point, plot_losses, early_stopping, reduce_lr]


# history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=4000, verbose=0)
history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=4000, verbose=0, callbacks=callbacks)


pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='test_loss')
pyplot.legend()
pyplot.show()
# Out:
# loss =  0.13533897697925568 , val_loss =  0.3714809379407338
# Epoch 00281: early stopping

# %%
x1 = np.arange(0, 10, 0.1)
np.random.shuffle(x1)
x2 = np.arange(0, 10, 0.1)
np.random.shuffle(x2)

x = np.ones((x1.shape[0],2))
x[:,0] = x1
x[:,1] = x2
np.random.shuffle(x)

y = np.sum(x, axis=1)


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]



from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*5, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x.T[0],test_y)
plt.scatter(test_x.T[0],y_, color="r")
plt.show()
# Out:
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_190 (Dense)            (None, 10)                30
# _________________________________________________________________
# dense_191 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_192 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 42.868507385253906
# 40/40 [==============================] - 0s 6ms/sample - loss: 0.0632 - mean_squared_error: 0.0632
# loss= 0.06320069283246994
# mse= 0.0632007

# %%
print(x.shape)
print(x[:5])
print(y[:5])
# Out:
# (100, 2)
# [[6.7 1. ]
#  [4.9 3.8]
#  [2.  2. ]
#  [6.9 5.1]
#  [4.  3. ]]
# [ 7.7  8.7  4.  12.   7. ]

# %%
x = np.arange(0, 10, 0.1)
np.random.shuffle(x)
y1 = x%2
y2 = x%3

y = np.zeros((y.shape[0],2))
y[:,0] = y1
y[:,1] = y2


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
# model.add(Dense(1))
model.add(Dense(2))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*10, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x,test_y[:,0])
plt.scatter(test_x,y_[:,0], color="r")
plt.show()

plt.scatter(test_x,test_y[:,1])
plt.scatter(test_x,y_[:,1], color="r")
plt.show()
# Out:
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_193 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_194 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_195 (Dense)            (None, 2)                 22
# =================================================================
# Total params: 152
# Trainable params: 152
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 85.6468894481659
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4786 - mean_squared_error: 0.4786
# loss= 0.47856684923172
# mse= 0.47856683

# %%
x1 = np.arange(0, 10, 0.1)
np.random.shuffle(x1)
x2 = np.arange(0, 10, 0.1)
np.random.shuffle(x2)

x = np.ones((x1.shape[0],2))
x[:,0] = x1
x[:,1] = x2

z = x1 + x2
y1 = z%2
y2 = z%3

y = np.zeros((y.shape[0],2))
y[:,0] = y1
y[:,1] = y2


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
# model.add(Dense(1))
model.add(Dense(2))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*10, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x.T[0],test_y[:,0])
plt.scatter(test_x.T[0],y_[:,0], color="r")
plt.show()

plt.scatter(test_x.T[1],test_y[:,1])
plt.scatter(test_x.T[1],y_[:,1], color="r")
plt.show()
# Out:
# Model: "sequential_64"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_196 (Dense)            (None, 10)                30
# _________________________________________________________________
# dense_197 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_198 (Dense)            (None, 2)                 22
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 85.71060824394226
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.6724 - mean_squared_error: 0.6724
# loss= 0.6724094390869141
# mse= 0.6724094
